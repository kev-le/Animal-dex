# %%
import wikipedia
import wptools
import pandas as pd
import requests
import re
from xml.dom.minidom import parse
from xml.dom.minidom import getDOMImplementation
from bs4 import BeautifulSoup

# %%
def find_bird(request):
    html = requests.get(request)
    b = BeautifulSoup(html.text, 'lxml')

    m = 0

    for i in b.find_all(name='table', class_='infobox biota'):
        for j in i.find_all(name='tr'):
            for k in j.find_all(name='td', style=False, colspan=False):
                if m == 1:
                    kingdom = k.text
                if m == 3:
                    phylum = k.text
                if m == 7:
                    order = k.text
                if m == 9:
                    family = k.text
                m = m + 1   

    return kingdom, phylum, order, family

# %%
#birds
bird_df = pd.DataFrame(columns=['breed', 'summary', 'image', 'conservation_status', 'kingdom', 'phylum',
                               'order', 'family', 'binomial_name'])

html = requests.get('https://en.wikipedia.org/wiki/List_of_birds_of_Canada')

#turn the HTML into a beautiful soup text object
b = BeautifulSoup(html.text, 'lxml')

for i in b.find_all(name='ul'):
    for j in i.find_all(name='li'):        
        #get the summary of each breed
        for link in j.find_all(name='a', href=True, title=True):
            breed = link['title']
            page = wptools.page(breed)
            parse = page.get_parse()

            try:
                if (parse.data['infobox']['status'] == 'LC'):
                    conservation_status = 'Least Concern'
                    
                if (parse.data['infobox']['status'] == 'NT'):
                    conservation_status = 'Near Threatened'
                    
                if (parse.data['infobox']['status'] == 'VU'):
                    conservation_status = 'Vulnerable'
                    
                if (parse.data['infobox']['status'] == 'EN'):
                    conservation_status = 'Endangered'
                    
                if (parse.data['infobox']['status'] == 'CR'):
                    conservation_status = 'Critically Endangered'
                    
                if (parse.data['infobox']['status'] == 'EW'):
                    conservation_status = 'Extinct In The Wild'
                    
                if (parse.data['infobox']['status'] == 'EX'):
                    conservation_status = 'Extinct'

            except:
                conservation_status = None
            
            restbase = page.get_restbase('/page/summary/')
            url = restbase.data['url']
            
            kingdom, phylum, order, family = find_bird(url)
            
            try:
                genus = parse.data['infobox']['genus']
            except:
                genus = None
            
            try:
                species = parse.data['infobox']['species']
            except: 
                species = None
            
            try: 
                binomial_name = genus + ' ' + species
            except:
                try:
                    binomial_name = parse.data['infobox']['taxon']
                except:
                    binomial_name = None
            
            try:
                image = parse.data['image'][0]['url']
            except:
                image = 'https://user-images.githubusercontent.com/24848110/33519396-7e56363c-d79d-11e7-969b-09782f5ccbab.png'
            summary = wikipedia.WikipediaPage(breed).summary

            bird_df = bird_df.append({'breed':breed, 'summary': summary, 'image':image,
                                     'conservation_status': conservation_status, 'kingdom': kingdom,
                                      'phylum': phylum, 'order': order, 'family': family, 
                                      'binomial_name': binomial_name},
                                     ignore_index = True)
# Out:
# en.wikipedia.org (parse) Black-bellied whistling-duck
# en.wikipedia.org (imageinfo) File:Whistling duck flight02 - natur...
# Black-bellied whistling duck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Whistling...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 1241519
#   parsetree: <str(15922)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Black-bellied whistling duck
#   wikibase: Q752461
#   wikidata_url: https://www.wikidata.org/wiki/Q752461
#   wikitext: <str(11088)> {{Use dmy dates|date=July 2013}}{{Species...
# }
# en.wikipedia.org (restbase) /page/summary/Black-bellied whistling duck
# Black-bellied whistling duck (en) data
# {
#   description: species of bird
#   exhtml: <str(830)> <p>The <b>black-bellied whistling-duck</b>, f...
#   exrest: <str(809)> The black-bellied whistling-duck, formerly ca...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Whistling...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 1241519
#   parsetree: <str(15922)> <root><template><title>Use dmy dates</ti...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Black-bellied_whistling_duck
#   url: https://en.wikipedia.org/wiki/Black-bellied whistling duck
#   url_raw: <str(69)> https://en.wikipedia.org/wiki/Black-bellied w...
#   wikibase: Q752461
#   wikidata_url: https://www.wikidata.org/wiki/Q752461
#   wikitext: <str(11088)> {{Use dmy dates|date=July 2013}}{{Species...
# }
# en.wikipedia.org (parse) Fulvous whistling-duck
# en.wikipedia.org (imageinfo) File:Dendrocygna bicolor wilhelma.jpg
# Fulvous whistling duck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dendrocyg...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 729708
#   parsetree: <str(41524)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Fulvous whistling duck
#   wikibase: Q740741
#   wikidata_url: https://www.wikidata.org/wiki/Q740741
#   wikitext: <str(27375)> {{short description|A species of bird in ...
# }
# en.wikipedia.org (restbase) /page/summary/Fulvous whistling duck
# Fulvous whistling duck (en) data
# {
#   description: <str(73)> A species of bird in the family Anatidae,...
#   exhtml: <str(1047)> <p>The <b>fulvous whistling duck</b> or <b>f...
#   exrest: <str(1026)> The fulvous whistling duck or fulvous tree d...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Dendrocyg...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 729708
#   parsetree: <str(41524)> <root><template><title>short description...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Fulvous_whistling_duck
#   url: https://en.wikipedia.org/wiki/Fulvous whistling duck
#   url_raw: https://en.wikipedia.org/wiki/Fulvous whistling duck?ac...
#   wikibase: Q740741
#   wikidata_url: https://www.wikidata.org/wiki/Q740741
#   wikitext: <str(27375)> {{short description|A species of bird in ...
# }
# en.wikipedia.org (parse) Emperor goose
# en.wikipedia.org (imageinfo) File:Emperor.goose.arp.750pix.jpg
# Emperor goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Emperor.g...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anser_cana...
#   pageid: 304218
#   parsetree: <str(32828)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Emperor goose
#   wikibase: Q755653
#   wikidata_url: https://www.wikidata.org/wiki/Q755653
#   wikitext: <str(20837)> {{Use dmy dates|date=February 2019}}{{spe...
# }
# en.wikipedia.org (restbase) /page/summary/Emperor goose
# Emperor goose (en) data
# {
#   description: species of bird
#   exhtml: <str(1118)> <p>The <b>emperor goose</b>, also known as t...
#   exrest: <str(1090)> The emperor goose, also known as the beach g...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Emperor.g...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anser_cana...
#   pageid: 304218
#   parsetree: <str(32828)> <root><template><title>Use dmy dates</ti...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Emperor_goose
#   url: https://en.wikipedia.org/wiki/Emperor goose
#   url_raw: https://en.wikipedia.org/wiki/Emperor goose?action=raw
#   wikibase: Q755653
#   wikidata_url: https://www.wikidata.org/wiki/Q755653
#   wikitext: <str(20837)> {{Use dmy dates|date=February 2019}}{{spe...
# }
# en.wikipedia.org (parse) Snow goose
# en.wikipedia.org (imageinfo) File:Snow goose in Central Park (331...
# Snow goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Snow goos...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 199013
#   parsetree: <str(24980)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Snow goose
#   wikibase: Q27074540
#   wikidata_url: https://www.wikidata.org/wiki/Q27074540
#   wikitext: <str(18388)> {{about|species of goose|other uses|snow ...
# }
# en.wikipedia.org (restbase) /page/summary/Snow goose
# Snow goose (en) data
# {
#   description: species of bird
#   exhtml: <str(580)> <p>The <b>snow goose</b>, consisting of both ...
#   exrest: <str(531)> The snow goose, consisting of both a white mo...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Snow goos...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 199013
#   parsetree: <str(24980)> <root><template><title>about</title><par...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Snow_goose
#   url: https://en.wikipedia.org/wiki/Snow goose
#   url_raw: https://en.wikipedia.org/wiki/Snow goose?action=raw
#   wikibase: Q27074540
#   wikidata_url: https://www.wikidata.org/wiki/Q27074540
#   wikitext: <str(18388)> {{about|species of goose|other uses|snow ...
# }
# en.wikipedia.org (parse) Ross's goose
# en.wikipedia.org (imageinfo) File:Ross's Goose (Chen rossii) (233...
# Ross's goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': "File:Ross's Go...
#   infobox: <dict(11)> name, image, image_caption, status, status_s...
#   iwlinks: <list(2)> https://species.wikimedia.org/wiki/Anser_ross...
#   pageid: 539045
#   parsetree: <str(12492)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Ross's goose
#   wikibase: Q244320
#   wikidata_url: https://www.wikidata.org/wiki/Q244320
#   wikitext: <str(9097)> {{speciesbox| name = Ross's goose| image =...
# }
# en.wikipedia.org (restbase) /page/summary/Ross's goose
# Ross's goose (en) data
# {
#   description: species of bird
#   exhtml: <str(397)> <p><b>Ross's goose</b> is a white goose with ...
#   exrest: <str(383)> Ross's goose is a white goose with black wing...
#   image: <list(3)> {'kind': 'parse-image', 'file': "File:Ross's Go...
#   infobox: <dict(11)> name, image, image_caption, status, status_s...
#   iwlinks: <list(2)> https://species.wikimedia.org/wiki/Anser_ross...
#   pageid: 539045
#   parsetree: <str(12492)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Ross's_goose
#   url: https://en.wikipedia.org/wiki/Ross's goose
#   url_raw: https://en.wikipedia.org/wiki/Ross's goose?action=raw
#   wikibase: Q244320
#   wikidata_url: https://www.wikidata.org/wiki/Q244320
#   wikitext: <str(9097)> {{speciesbox| name = Ross's goose| image =...
# }
# en.wikipedia.org (parse) Greylag goose
# en.wikipedia.org (imageinfo) File:Greylag Goose - St James's Park...
# Greylag goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': "File:Greylag G...
#   infobox: <dict(13)> name, status, status_system, image, image_ca...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198766
#   parsetree: <str(36268)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Greylag goose
#   wikibase: Q25882
#   wikidata_url: https://www.wikidata.org/wiki/Q25882
#   wikitext: <str(26564)> {{short description|Species of bird}}{{re...
# }
# en.wikipedia.org (restbase) /page/summary/Greylag goose
# Greylag goose (en) data
# {
#   description: Species of bird
#   exhtml: <str(696)> <p>The <b>greylag goose</b> is a species of l...
#   exrest: <str(661)> The greylag goose is a species of large goose...
#   image: <list(3)> {'kind': 'parse-image', 'file': "File:Greylag G...
#   infobox: <dict(13)> name, status, status_system, image, image_ca...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198766
#   parsetree: <str(36268)> <root><template><title>short description...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Greylag_goose
#   url: https://en.wikipedia.org/wiki/Greylag goose
#   url_raw: https://en.wikipedia.org/wiki/Greylag goose?action=raw
#   wikibase: Q25882
#   wikidata_url: https://www.wikidata.org/wiki/Q25882
#   wikitext: <str(26564)> {{short description|Species of bird}}{{re...
# }
# en.wikipedia.org (parse) Greater white-fronted goose
# en.wikipedia.org (imageinfo) File:Anser albifrons 30050.JPG
# Greater white-fronted goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anser alb...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198770
#   parsetree: <str(24409)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Greater white-fronted goose
#   wikibase: Q172093
#   wikidata_url: https://www.wikidata.org/wiki/Q172093
#   wikitext: <str(19046)> {{speciesbox| name = Greater white-fronte...
# }
# en.wikipedia.org (restbase) /page/summary/Greater white-fronted goose
# Greater white-fronted goose (en) data
# {
#   description: species of bird
#   exhtml: <str(663)> <p>The <b>greater white-fronted goose</b> is ...
#   exrest: <str(607)> The greater white-fronted goose is a species ...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Anser alb...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198770
#   parsetree: <str(24409)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Greater_white-fronted_goose
#   url: https://en.wikipedia.org/wiki/Greater white-fronted goose
#   url_raw: <str(68)> https://en.wikipedia.org/wiki/Greater white-f...
#   wikibase: Q172093
#   wikidata_url: https://www.wikidata.org/wiki/Q172093
#   wikitext: <str(19046)> {{speciesbox| name = Greater white-fronte...
# }
# en.wikipedia.org (parse) Taiga bean-goose
# en.wikipedia.org (imageinfo) File:Bean.goose.600pix.jpg
# Taiga bean goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bean.goos...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198773
#   parsetree: <str(13563)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Taiga bean goose
#   wikibase: Q26452
#   wikidata_url: https://www.wikidata.org/wiki/Q26452
#   wikitext: <str(6971)> {{speciesbox| name = Taiga bean goose| ima...
# }
# en.wikipedia.org (restbase) /page/summary/Taiga bean goose
# Taiga bean goose (en) data
# {
#   description: species of bird
#   exhtml: <str(399)> <p>The <b>taiga bean goose</b> is a goose tha...
#   exrest: <str(385)> The taiga bean goose is a goose that breeds i...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Bean.goos...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 198773
#   parsetree: <str(13563)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Taiga_bean_goose
#   url: https://en.wikipedia.org/wiki/Taiga bean goose
#   url_raw: https://en.wikipedia.org/wiki/Taiga bean goose?action=raw
#   wikibase: Q26452
#   wikidata_url: https://www.wikidata.org/wiki/Q26452
#   wikitext: <str(6971)> {{speciesbox| name = Taiga bean goose| ima...
# }
# en.wikipedia.org (parse) Tundra bean-goose
# en.wikipedia.org (imageinfo) File:Tundra Bean Goose.jpg
# Tundra bean goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tundra Be...
#   infobox: <dict(6)> name, image, image_caption, genus, species, a...
#   iwlinks: <list(3)> https://de.wikipedia.org/wiki/Tierstimmenarch...
#   pageid: 29661944
#   parsetree: <str(5948)> <root><template><title>Speciesbox</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Tundra bean goose
#   wikibase: Q673280
#   wikidata_url: https://www.wikidata.org/wiki/Q673280
#   wikitext: <str(3410)> {{Speciesbox| name = Tundra bean goose| im...
# }
# en.wikipedia.org (restbase) /page/summary/Tundra bean goose
# Tundra bean goose (en) data
# {
#   description: species of bird
#   exhtml: <str(377)> <p>The <b> tundra bean goose</b> is a goose t...
#   exrest: <str(363)> The  tundra bean goose is a goose that breeds...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Tundra Be...
#   infobox: <dict(6)> name, image, image_caption, genus, species, a...
#   iwlinks: <list(3)> https://de.wikipedia.org/wiki/Tierstimmenarch...
#   pageid: 29661944
#   parsetree: <str(5948)> <root><template><title>Speciesbox</title>...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Tundra_bean_goose
#   url: https://en.wikipedia.org/wiki/Tundra bean goose
#   url_raw: https://en.wikipedia.org/wiki/Tundra bean goose?action=raw
#   wikibase: Q673280
#   wikidata_url: https://www.wikidata.org/wiki/Q673280
#   wikitext: <str(3410)> {{Speciesbox| name = Tundra bean goose| im...
# }
# en.wikipedia.org (parse) Pink-footed goose
# en.wikipedia.org (imageinfo) File:Anser brachyrhynchus.jpg
# Pink-footed goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anser bra...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anser_brac...
#   pageid: 198999
#   parsetree: <str(12171)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Pink-footed goose
#   wikibase: Q209419
#   wikidata_url: https://www.wikidata.org/wiki/Q209419
#   wikitext: <str(8177)> {{speciesbox| name = Pink-footed goose| im...
# }
# en.wikipedia.org (restbase) /page/summary/Pink-footed goose
# Pink-footed goose (en) data
# {
#   description: species of bird
#   exhtml: <str(434)> <p>The <b>pink-footed goose</b> is a goose wh...
#   exrest: <str(392)> The pink-footed goose is a goose which breeds...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Anser bra...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anser_brac...
#   pageid: 198999
#   parsetree: <str(12171)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Pink-footed_goose
#   url: https://en.wikipedia.org/wiki/Pink-footed goose
#   url_raw: https://en.wikipedia.org/wiki/Pink-footed goose?action=raw
#   wikibase: Q209419
#   wikidata_url: https://www.wikidata.org/wiki/Q209419
#   wikitext: <str(8177)> {{speciesbox| name = Pink-footed goose| im...
# }
# en.wikipedia.org (parse) Brant (goose)
# en.wikipedia.org (imageinfo) File:Brent Goose.jpg
# Brant (goose) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Brent Goo...
#   infobox: <dict(10)> status, status_system, image, image_caption,...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 2424774
#   parsetree: <str(16341)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Brant (goose)
#   wikibase: Q27050
#   wikidata_url: https://www.wikidata.org/wiki/Q27050
#   wikitext: <str(10522)> {{Use dmy dates|date=July 2013}}{{Page nu...
# }
# en.wikipedia.org (restbase) /page/summary/Brant (goose)
# Brant (goose) (en) data
# {
#   description: species of goose
#   exhtml: <str(153)> <p>The <b>brant</b>, or <b>brent goose</b>, i...
#   exrest: <str(125)> The brant, or brent goose, is a species of go...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Brent Goo...
#   infobox: <dict(10)> status, status_system, image, image_caption,...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 2424774
#   parsetree: <str(16341)> <root><template><title>Use dmy dates</ti...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Brant_(goose)
#   url: https://en.wikipedia.org/wiki/Brant (goose)
#   url_raw: https://en.wikipedia.org/wiki/Brant (goose)?action=raw
#   wikibase: Q27050
#   wikidata_url: https://www.wikidata.org/wiki/Q27050
#   wikitext: <str(10522)> {{Use dmy dates|date=July 2013}}{{Page nu...
# }
# en.wikipedia.org (parse) Barnacle goose
# en.wikipedia.org (imageinfo) File:Barnacle-Goose.jpg
# Barnacle goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Barnacle-...
#   infobox: <dict(7)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Branta_leu...
#   pageid: 199527
#   parsetree: <str(18493)> <root><template><title>distinguish</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Barnacle goose
#   wikibase: Q26680
#   wikidata_url: https://www.wikidata.org/wiki/Q26680
#   wikitext: <str(13820)> {{distinguish|Goose barnacle}}{{speciesbo...
# }
# en.wikipedia.org (restbase) /page/summary/Barnacle goose
# Barnacle goose (en) data
# {
#   description: species of bird
#   exhtml: <str(331)> <p>The <b>barnacle goose</b> belongs to the g...
#   exrest: <str(303)> The barnacle goose belongs to the genus Brant...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Barnacle-...
#   infobox: <dict(7)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Branta_leu...
#   pageid: 199527
#   parsetree: <str(18493)> <root><template><title>distinguish</titl...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Barnacle_goose
#   url: https://en.wikipedia.org/wiki/Barnacle goose
#   url_raw: https://en.wikipedia.org/wiki/Barnacle goose?action=raw
#   wikibase: Q26680
#   wikidata_url: https://www.wikidata.org/wiki/Q26680
#   wikitext: <str(13820)> {{distinguish|Goose barnacle}}{{speciesbo...
# }
# en.wikipedia.org (parse) Cackling goose
# en.wikipedia.org (imageinfo) File:AleutianCanadaGoose2.jpg
# Cackling goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:AleutianC...
#   infobox: <dict(12)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 1246114
#   parsetree: <str(11242)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Cackling goose
#   wikibase: Q244189
#   wikidata_url: https://www.wikidata.org/wiki/Q244189
#   wikitext: <str(8990)> {{speciesbox| name = Cackling goose| image...
# }
# en.wikipedia.org (restbase) /page/summary/Cackling goose
# Cackling goose (en) data
# {
#   description: species of bird
#   exhtml: <str(207)> <p>The <b>cackling goose</b> is a North Ameri...
#   exrest: <str(179)> The cackling goose is a North American bird o...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:AleutianC...
#   infobox: <dict(12)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 1246114
#   parsetree: <str(11242)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Cackling_goose
#   url: https://en.wikipedia.org/wiki/Cackling goose
#   url_raw: https://en.wikipedia.org/wiki/Cackling goose?action=raw
#   wikibase: Q244189
#   wikidata_url: https://www.wikidata.org/wiki/Q244189
#   wikitext: <str(8990)> {{speciesbox| name = Cackling goose| image...
# }
# en.wikipedia.org (parse) Canada goose
# en.wikipedia.org (imageinfo) File:Canada goose on Seedskadee NWR ...
# Canada goose (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Canada go...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 218972
#   parsetree: <str(68474)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Canada goose
#   wikibase: Q26733
#   wikidata_url: https://www.wikidata.org/wiki/Q26733
#   wikitext: <str(54654)> {{short description|Goose species}}{{for|...
# }
# en.wikipedia.org (restbase) /page/summary/Canada goose
# Canada goose (en) data
# {
#   description: Goose species
#   exhtml: <str(486)> <p>The <b>Canada goose</b> is a large wild go...
#   exrest: <str(472)> The Canada goose is a large wild goose specie...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Canada go...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 218972
#   parsetree: <str(68474)> <root><template><title>short description...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Canada_goose
#   url: https://en.wikipedia.org/wiki/Canada goose
#   url_raw: https://en.wikipedia.org/wiki/Canada goose?action=raw
#   wikibase: Q26733
#   wikidata_url: https://www.wikidata.org/wiki/Q26733
#   wikitext: <str(54654)> {{short description|Goose species}}{{for|...
# }
# en.wikipedia.org (parse) Mute swan
# en.wikipedia.org (imageinfo) File:Mute swan Vrhnika.jpg
# Mute swan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Mute swan...
#   infobox: <dict(10)> name, status, status_system, image, genus, s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 19614307
#   parsetree: <str(46118)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Mute swan
#   wikibase: Q25402
#   wikidata_url: https://www.wikidata.org/wiki/Q25402
#   wikitext: <str(33663)> {{Use dmy dates|date=May 2016}}{{speciesb...
# }
# en.wikipedia.org (restbase) /page/summary/Mute swan
# Mute swan (en) data
# {
#   description: species of bird
#   exhtml: <str(512)> <p>The <b>mute swan</b> is a species of swan ...
#   exrest: <str(498)> The mute swan is a species of swan and a memb...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Mute swan...
#   infobox: <dict(10)> name, status, status_system, image, genus, s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 19614307
#   parsetree: <str(46118)> <root><template><title>Use dmy dates</ti...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Mute_swan
#   url: https://en.wikipedia.org/wiki/Mute swan
#   url_raw: https://en.wikipedia.org/wiki/Mute swan?action=raw
#   wikibase: Q25402
#   wikidata_url: https://www.wikidata.org/wiki/Q25402
#   wikitext: <str(33663)> {{Use dmy dates|date=May 2016}}{{speciesb...
# }
# en.wikipedia.org (parse) Trumpeter swan
# en.wikipedia.org (imageinfo) File:Trumpeter swans in winter.jpg
# Trumpeter swan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Trumpeter...
#   infobox: <dict(7)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 696215
#   parsetree: <str(46705)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Trumpeter swan
#   wikibase: Q733375
#   wikidata_url: https://www.wikidata.org/wiki/Q733375
#   wikitext: <str(34779)> {{speciesbox| name = Trumpeter swan| stat...
# }
# en.wikipedia.org (restbase) /page/summary/Trumpeter swan
# Trumpeter swan (en) data
# {
#   description: species of bird
#   exhtml: <str(742)> <p>The <b>trumpeter swan</b> is a species of ...
#   exrest: <str(728)> The trumpeter swan is a species of swan found...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Trumpeter...
#   infobox: <dict(7)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 696215
#   parsetree: <str(46705)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Trumpeter_swan
#   url: https://en.wikipedia.org/wiki/Trumpeter swan
#   url_raw: https://en.wikipedia.org/wiki/Trumpeter swan?action=raw
#   wikibase: Q733375
#   wikidata_url: https://www.wikidata.org/wiki/Q733375
#   wikitext: <str(34779)> {{speciesbox| name = Trumpeter swan| stat...
# }
# en.wikipedia.org (parse) Tundra swan
# en.wikipedia.org (imageinfo) File:Cygnus bewickii 01.jpg
# Tundra swan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cygnus be...
#   infobox: <dict(14)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 232255
#   parsetree: <str(37486)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Tundra swan
#   wikibase: Q26603
#   wikidata_url: https://www.wikidata.org/wiki/Q26603
#   wikitext: <str(26039)> {{speciesbox| name = Tundra swan<br/>(Bew...
# }
# en.wikipedia.org (restbase) /page/summary/Tundra swan
# Tundra swan (en) data
# {
#   description: species of bird
#   exhtml: <str(564)> <p>The <b>tundra swan</b> is a small Holarcti...
#   exrest: <str(515)> The tundra swan is a small Holarctic swan. Th...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Cygnus be...
#   infobox: <dict(14)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 232255
#   parsetree: <str(37486)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Tundra_swan
#   url: https://en.wikipedia.org/wiki/Tundra swan
#   url_raw: https://en.wikipedia.org/wiki/Tundra swan?action=raw
#   wikibase: Q26603
#   wikidata_url: https://www.wikidata.org/wiki/Q26603
#   wikitext: <str(26039)> {{speciesbox| name = Tundra swan<br/>(Bew...
# }
# en.wikipedia.org (parse) Whooper swan
# en.wikipedia.org (imageinfo) File:Cygnus cygnus Singschwan.jpg
# Whooper swan (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cygnus cy...
#   infobox: <dict(12)> name, status, status_system, image, image2, ...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 307018
#   parsetree: <str(17343)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Whooper swan
#   wikibase: Q25612
#   wikidata_url: https://www.wikidata.org/wiki/Q25612
#   wikitext: <str(10549)> {{speciesbox| name = Whooper swan| status...
# }
# en.wikipedia.org (restbase) /page/summary/Whooper swan
# Whooper swan (en) data
# {
#   description: species of bird
#   exhtml: <str(433)> <p>The <b>whooper swan</b>, also as the <b>co...
#   exrest: <str(384)> The whooper swan, also as the common swan, pr...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Cygnus cy...
#   infobox: <dict(12)> name, status, status_system, image, image2, ...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 307018
#   parsetree: <str(17343)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Whooper_swan
#   url: https://en.wikipedia.org/wiki/Whooper swan
#   url_raw: https://en.wikipedia.org/wiki/Whooper swan?action=raw
#   wikibase: Q25612
#   wikidata_url: https://www.wikidata.org/wiki/Q25612
#   wikitext: <str(10549)> {{speciesbox| name = Whooper swan| status...
# }
# en.wikipedia.org (parse) Ruddy shelduck
# en.wikipedia.org (imageinfo) File:A couple of Tadorna ferruginea.jpg
# Ruddy shelduck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:A couple ...
#   infobox: <dict(9)> name, status, status_system, image, image_cap...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Tadorna_fe...
#   pageid: 355733
#   parsetree: <str(21562)> <root><template><title>Good article</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Ruddy shelduck
#   wikibase: Q170723
#   wikidata_url: https://www.wikidata.org/wiki/Q170723
#   wikitext: <str(15937)> {{Good article}}{{speciesbox| name = Rudd...
# }
# en.wikipedia.org (restbase) /page/summary/Ruddy shelduck
# Ruddy shelduck (en) data
# {
#   description: species of bird
#   exhtml: <str(560)> <p>The <b>ruddy shelduck</b>, known in India ...
#   exrest: <str(539)> The ruddy shelduck, known in India as the Bra...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:A couple ...
#   infobox: <dict(9)> name, status, status_system, image, image_cap...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Tadorna_fe...
#   pageid: 355733
#   parsetree: <str(21562)> <root><template><title>Good article</tit...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Ruddy_shelduck
#   url: https://en.wikipedia.org/wiki/Ruddy shelduck
#   url_raw: https://en.wikipedia.org/wiki/Ruddy shelduck?action=raw
#   wikibase: Q170723
#   wikidata_url: https://www.wikidata.org/wiki/Q170723
#   wikitext: <str(15937)> {{Good article}}{{speciesbox| name = Rudd...
# }
# en.wikipedia.org (parse) Common shelduck
# en.wikipedia.org (imageinfo) File:Common Shelduck (Tadorna tadorn...
# Common shelduck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Common Sh...
#   infobox: <dict(13)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 258880
#   parsetree: <str(10111)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Common shelduck
#   wikibase: Q25761
#   wikidata_url: https://www.wikidata.org/wiki/Q25761
#   wikitext: <str(6962)> {{speciesbox|name = Common shelduck|image ...
# }
# en.wikipedia.org (restbase) /page/summary/Common shelduck
# Common shelduck (en) data
# {
#   description: species of bird
#   exhtml: <str(447)> <p>The <b>common shelduck</b> is a waterfowl ...
#   exrest: <str(419)> The common shelduck is a waterfowl species of...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Common Sh...
#   infobox: <dict(13)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 258880
#   parsetree: <str(10111)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Common_shelduck
#   url: https://en.wikipedia.org/wiki/Common shelduck
#   url_raw: https://en.wikipedia.org/wiki/Common shelduck?action=raw
#   wikibase: Q25761
#   wikidata_url: https://www.wikidata.org/wiki/Q25761
#   wikitext: <str(6962)> {{speciesbox|name = Common shelduck|image ...
# }
# en.wikipedia.org (parse) Wood duck
# en.wikipedia.org (imageinfo) File:Wood Duck (Aix sponsa), Parc du...
# Wood duck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Wood Duck...
#   infobox: <dict(13)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 252112
#   parsetree: <str(16848)> <root><template><title>for</title><part>...
#   requests: <list(2)> parse, imageinfo
#   title: Wood duck
#   wikibase: Q322159
#   wikidata_url: https://www.wikidata.org/wiki/Q322159
#   wikitext: <str(11189)> {{for|the Australian species|Australian w...
# }
# en.wikipedia.org (restbase) /page/summary/Wood duck
# Wood duck (en) data
# {
#   description: species of bird
#   exhtml: <str(162)> <p>The <b>wood duck</b> or <b>Carolina duck</...
#   exrest: <str(141)> The wood duck or Carolina duck is a species o...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Wood Duck...
#   infobox: <dict(13)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 252112
#   parsetree: <str(16848)> <root><template><title>for</title><part>...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Wood_duck
#   url: https://en.wikipedia.org/wiki/Wood duck
#   url_raw: https://en.wikipedia.org/wiki/Wood duck?action=raw
#   wikibase: Q322159
#   wikidata_url: https://www.wikidata.org/wiki/Q322159
#   wikitext: <str(11189)> {{for|the Australian species|Australian w...
# }
# en.wikipedia.org (parse) Baikal teal
# en.wikipedia.org (imageinfo) File:Anas.formosa.4.jpg
# Baikal teal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anas.form...
#   infobox: <dict(12)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anas_formo...
#   pageid: 542356
#   parsetree: <str(11145)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Baikal teal
#   wikibase: Q330710
#   wikidata_url: https://www.wikidata.org/wiki/Q330710
#   wikitext: <str(8571)> {{speciesbox| name = Baikal teal| image = ...
# }
# en.wikipedia.org (restbase) /page/summary/Baikal teal
# Baikal teal (en) data
# {
#   description: species of bird
#   exhtml: <str(167)> <p>The <b>Baikal teal</b>, also called the <b...
#   exrest: <str(139)> The Baikal teal, also called the bimaculate d...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Anas.form...
#   infobox: <dict(12)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Anas_formo...
#   pageid: 542356
#   parsetree: <str(11145)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Baikal_teal
#   url: https://en.wikipedia.org/wiki/Baikal teal
#   url_raw: https://en.wikipedia.org/wiki/Baikal teal?action=raw
#   wikibase: Q330710
#   wikidata_url: https://www.wikidata.org/wiki/Q330710
#   wikitext: <str(8571)> {{speciesbox| name = Baikal teal| image = ...
# }
# en.wikipedia.org (parse) Garganey
# en.wikipedia.org (imageinfo) File:Garganey (Anas querquedula) RWD3.jpg
# Garganey (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Garganey ...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251572
#   parsetree: <str(11029)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Garganey
#   wikibase: Q25644
#   wikidata_url: https://www.wikidata.org/wiki/Q25644
#   wikitext: <str(7870)> {{speciesbox| name = Garganey| image = Gar...
# }
# en.wikipedia.org (restbase) /page/summary/Garganey
# Garganey (en) data
# {
#   description: species of bird
#   exhtml: <str(437)> <p>The <b>garganey</b> is a small dabbling du...
#   exrest: <str(423)> The garganey is a small dabbling duck. It bre...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Garganey ...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251572
#   parsetree: <str(11029)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Garganey
#   url: https://en.wikipedia.org/wiki/Garganey
#   url_raw: https://en.wikipedia.org/wiki/Garganey?action=raw
#   wikibase: Q25644
#   wikidata_url: https://www.wikidata.org/wiki/Q25644
#   wikitext: <str(7870)> {{speciesbox| name = Garganey| image = Gar...
# }
# en.wikipedia.org (parse) Blue-winged teal
# en.wikipedia.org (imageinfo) File:Blue-Winged Teal.jpg
# Blue-winged teal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Blue-Wing...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251176
#   parsetree: <str(25690)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Blue-winged teal
#   wikibase: Q504148
#   wikidata_url: https://www.wikidata.org/wiki/Q504148
#   wikitext: <str(17428)> {{speciesbox| name = Blue-winged teal| st...
# }
# en.wikipedia.org (restbase) /page/summary/Blue-winged teal
# Blue-winged teal (en) data
# {
#   description: species of duck
#   exhtml: <str(373)> <p>The <b>blue-winged teal</b> is a species o...
#   exrest: <str(359)> The blue-winged teal is a species of bird in ...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Blue-Wing...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251176
#   parsetree: <str(25690)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Blue-winged_teal
#   url: https://en.wikipedia.org/wiki/Blue-winged teal
#   url_raw: https://en.wikipedia.org/wiki/Blue-winged teal?action=raw
#   wikibase: Q504148
#   wikidata_url: https://www.wikidata.org/wiki/Q504148
#   wikitext: <str(17428)> {{speciesbox| name = Blue-winged teal| st...
# }
# en.wikipedia.org (parse) Cinnamon teal
# en.wikipedia.org (imageinfo) File:Sarcelle cannelle.jpg
# Cinnamon teal (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sarcelle ...
#   infobox: <dict(12)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251182
#   parsetree: <str(9855)> <root><template><title>Speciesbox</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Cinnamon teal
#   wikibase: Q167164
#   wikidata_url: https://www.wikidata.org/wiki/Q167164
#   wikitext: <str(6625)> {{Speciesbox| name = Cinnamon teal| image ...
# }
# en.wikipedia.org (restbase) /page/summary/Cinnamon teal
# Cinnamon teal (en) data
# {
#   description: species of bird
#   exhtml: <str(262)> <p>The <b>cinnamon teal</b> is a species of d...
#   exrest: <str(248)> The cinnamon teal is a species of duck found ...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Sarcelle ...
#   infobox: <dict(12)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 251182
#   parsetree: <str(9855)> <root><template><title>Speciesbox</title>...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Cinnamon_teal
#   url: https://en.wikipedia.org/wiki/Cinnamon teal
#   url_raw: https://en.wikipedia.org/wiki/Cinnamon teal?action=raw
#   wikibase: Q167164
#   wikidata_url: https://www.wikidata.org/wiki/Q167164
#   wikitext: <str(6625)> {{Speciesbox| name = Cinnamon teal| image ...
# }
# en.wikipedia.org (parse) Northern shoveler
# en.wikipedia.org (imageinfo) File:Northern shoveler Steve Sinclai...
# Northern shoveler (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Northern ...
#   infobox: <dict(15)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 226344
#   parsetree: <str(19292)> <root><template><title>Speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Northern shoveler
#   wikibase: Q25940
#   wikidata_url: https://www.wikidata.org/wiki/Q25940
#   wikitext: <str(14146)> {{Speciesbox| name = Northern shoveler | ...
# }
# en.wikipedia.org (restbase) /page/summary/Northern shoveler
# Northern shoveler (en) data
# {
#   description: species of bird
#   exhtml: <str(525)> <p>The <b>northern shoveler</b>, known simply...
#   exrest: <str(504)> The northern shoveler, known simply in Britai...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Northern ...
#   infobox: <dict(15)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(6)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 226344
#   parsetree: <str(19292)> <root><template><title>Speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Northern_shoveler
#   url: https://en.wikipedia.org/wiki/Northern shoveler
#   url_raw: https://en.wikipedia.org/wiki/Northern shoveler?action=raw
#   wikibase: Q25940
#   wikidata_url: https://www.wikidata.org/wiki/Q25940
#   wikitext: <str(14146)> {{Speciesbox| name = Northern shoveler | ...
# }
# en.wikipedia.org (parse) Gadwall
# en.wikipedia.org (imageinfo) File:Gadwall-Anas-strepera.jpg
# Gadwall (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Gadwall-A...
#   infobox: <dict(14)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 226454
#   parsetree: <str(16755)> <root><template><title>Other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: Gadwall
#   wikibase: Q25889
#   wikidata_url: https://www.wikidata.org/wiki/Q25889
#   wikitext: <str(11097)> {{Other uses}}{{speciesbox| name = Gadwal...
# }
# en.wikipedia.org (restbase) /page/summary/Gadwall
# Gadwall (en) data
# {
#   description: species of bird
#   exhtml: <str(90)> <p>The <b>gadwall</b> is a common and widespre...
#   exrest: <str(76)> The gadwall is a common and widespread dabblin...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Gadwall-A...
#   infobox: <dict(14)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 226454
#   parsetree: <str(16755)> <root><template><title>Other uses</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Gadwall
#   url: https://en.wikipedia.org/wiki/Gadwall
#   url_raw: https://en.wikipedia.org/wiki/Gadwall?action=raw
#   wikibase: Q25889
#   wikidata_url: https://www.wikidata.org/wiki/Q25889
#   wikitext: <str(11097)> {{Other uses}}{{speciesbox| name = Gadwal...
# }
# en.wikipedia.org (parse) Falcated duck
# en.wikipedia.org (imageinfo) File:Falcated duck 1.jpg
# Falcated duck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Falcated ...
#   infobox: <dict(8)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 737709
#   parsetree: <str(23435)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Falcated duck
#   wikibase: Q339781
#   wikidata_url: https://www.wikidata.org/wiki/Q339781
#   wikitext: <str(18730)> {{speciesbox| name = Falcated duck| statu...
# }
# en.wikipedia.org (restbase) /page/summary/Falcated duck
# Falcated duck (en) data
# {
#   description: species of bird
#   exhtml: <str(99)> <p>The <b>falcated duck</b> or <b>falcated tea...
#   exrest: <str(78)> The falcated duck or falcated teal is a gadwal...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Falcated ...
#   infobox: <dict(8)> name, status, status_system, image, genus, sp...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 737709
#   parsetree: <str(23435)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Falcated_duck
#   url: https://en.wikipedia.org/wiki/Falcated duck
#   url_raw: https://en.wikipedia.org/wiki/Falcated duck?action=raw
#   wikibase: Q339781
#   wikidata_url: https://www.wikidata.org/wiki/Q339781
#   wikitext: <str(18730)> {{speciesbox| name = Falcated duck| statu...
# }
# en.wikipedia.org (parse) Eurasian wigeon
# en.wikipedia.org (imageinfo) File:Mareca penelope kuribo cropped.jpg
# Eurasian wigeon (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Mareca pe...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:M...
#   pageid: 226964
#   parsetree: <str(14413)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Eurasian wigeon
#   wikibase: Q26459
#   wikidata_url: https://www.wikidata.org/wiki/Q26459
#   wikitext: <str(7444)> {{speciesbox| name = Eurasian wigeon| stat...
# }
# en.wikipedia.org (restbase) /page/summary/Eurasian wigeon
# Eurasian wigeon (en) data
# {
#   description: duck
#   exhtml: <str(185)> <p>The <b>Eurasian wigeon</b>, also known as ...
#   exrest: <str(157)> The Eurasian wigeon, also known as widgeon is...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Mareca pe...
#   infobox: <dict(10)> name, status, status_system, image, image_ca...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Category:M...
#   pageid: 226964
#   parsetree: <str(14413)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Eurasian_wigeon
#   url: https://en.wikipedia.org/wiki/Eurasian wigeon
#   url_raw: https://en.wikipedia.org/wiki/Eurasian wigeon?action=raw
#   wikibase: Q26459
#   wikidata_url: https://www.wikidata.org/wiki/Q26459
#   wikitext: <str(7444)> {{speciesbox| name = Eurasian wigeon| stat...
# }
# en.wikipedia.org (parse) American wigeon
# en.wikipedia.org (imageinfo) File:Anas americana - drake.jpg
# American wigeon (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anas amer...
#   infobox: <dict(12)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:M...
#   pageid: 226965
#   parsetree: <str(18739)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: American wigeon
#   wikibase: Q703790
#   wikidata_url: https://www.wikidata.org/wiki/Q703790
#   wikitext: <str(10331)> {{speciesbox| name = American wigeon| ima...
# }
# en.wikipedia.org (restbase) /page/summary/American wigeon
# American wigeon (en) data
# {
#   description: species of bird
#   exhtml: <str(425)> <p>The <b>American wigeon</b>, also called a ...
#   exrest: <str(369)> The American wigeon, also called a baldpate, ...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Anas amer...
#   infobox: <dict(12)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:M...
#   pageid: 226965
#   parsetree: <str(18739)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: American_wigeon
#   url: https://en.wikipedia.org/wiki/American wigeon
#   url_raw: https://en.wikipedia.org/wiki/American wigeon?action=raw
#   wikibase: Q703790
#   wikidata_url: https://www.wikidata.org/wiki/Q703790
#   wikitext: <str(10331)> {{speciesbox| name = American wigeon| ima...
# }
# en.wikipedia.org (parse) Mallard
# en.wikipedia.org (imageinfo) File:Anas platyrhynchos male female ...
# Mallard (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anas plat...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 230456
#   parsetree: <str(112213)> <root><template><title>Other uses</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Mallard
#   wikibase: Q25348
#   wikidata_url: https://www.wikidata.org/wiki/Q25348
#   wikitext: <str(87915)> {{Other uses}}{{Redirect|Wild Duck|the pl...
# }
# en.wikipedia.org (restbase) /page/summary/Mallard
# Mallard (en) data
# {
#   description: species of dabbling duck
#   exhtml: <str(1147)> <p>The <b>mallard</b> is a dabbling duck tha...
#   exrest: <str(1133)> The mallard is a dabbling duck that breeds t...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Anas plat...
#   infobox: <dict(13)> name, image, image_caption, status, status_s...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 230456
#   parsetree: <str(112213)> <root><template><title>Other uses</titl...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Mallard
#   url: https://en.wikipedia.org/wiki/Mallard
#   url_raw: https://en.wikipedia.org/wiki/Mallard?action=raw
#   wikibase: Q25348
#   wikidata_url: https://www.wikidata.org/wiki/Q25348
#   wikitext: <str(87915)> {{Other uses}}{{Redirect|Wild Duck|the pl...
# }
# en.wikipedia.org (parse) American black duck
# en.wikipedia.org (imageinfo) File:Blackduck.jpg
# American black duck (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Blackduck...
#   infobox: <dict(10)> name, image, image_caption, status, status_s...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 250759
#   parsetree: <str(38183)> <root><template><title>good article</tit...
#   requests: <list(2)> parse, imageinfo
#   title: American black duck
#   wikibase: Q845292
#   wikidata_url: https://www.wikidata.org/wiki/Q845292
#   wikitext: <str(27940)> {{good article}}{{speciesbox| name = Amer...
# }
# en.wikipedia.org (restbase) /page/summary/American black duck
# American black duck (en) data
# {
# ...
#   pageid: 313127
#   parsetree: <str(37894)> <root><template><title>redirect</title><...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Northern_cardinal
#   url: https://en.wikipedia.org/wiki/Northern cardinal
#   url_raw: https://en.wikipedia.org/wiki/Northern cardinal?action=raw
#   wikibase: Q726389
#   wikidata_url: https://www.wikidata.org/wiki/Q726389
#   wikitext: <str(28544)> {{redirect|Red Cardinal|the plant|Erythri...
# }
# en.wikipedia.org (parse) Pyrrhuloxia
# en.wikipedia.org (imageinfo) File:Cardinalis sinuatus 3.jpg
# Pyrrhuloxia (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cardinali...
#   infobox: <dict(9)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Cardinalis...
#   pageid: 3113451
#   parsetree: <str(13486)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Pyrrhuloxia
#   wikibase: Q166985
#   wikidata_url: https://www.wikidata.org/wiki/Q166985
#   wikitext: <str(11123)> {{speciesbox| status = LC| status_system ...
# }
# en.wikipedia.org (restbase) /page/summary/Pyrrhuloxia
# Pyrrhuloxia (en) data
# {
#   description: species of bird
#   exhtml: <str(326)> <p>The <b>pyrrhuloxia</b> or <b>desert cardin...
#   exrest: <str(305)> The pyrrhuloxia or desert cardinal is a mediu...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Cardinali...
#   infobox: <dict(9)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Cardinalis...
#   pageid: 3113451
#   parsetree: <str(13486)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Pyrrhuloxia
#   url: https://en.wikipedia.org/wiki/Pyrrhuloxia
#   url_raw: https://en.wikipedia.org/wiki/Pyrrhuloxia?action=raw
#   wikibase: Q166985
#   wikidata_url: https://www.wikidata.org/wiki/Q166985
#   wikitext: <str(11123)> {{speciesbox| status = LC| status_system ...
# }
# en.wikipedia.org (parse) Rose-breasted grosbeak
# en.wikipedia.org (imageinfo) File:RosebreastedGrosbeak08.jpg
# Rose-breasted grosbeak (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Rosebreas...
#   infobox: <dict(13)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 373189
#   parsetree: <str(42076)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Rose-breasted grosbeak
#   wikibase: Q839834
#   wikidata_url: https://www.wikidata.org/wiki/Q839834
#   wikitext: <str(33030)> {{speciesbox| name = Rose-breasted grosbe...
# }
# en.wikipedia.org (restbase) /page/summary/Rose-breasted grosbeak
# Rose-breasted grosbeak (en) data
# {
#   description: species of bird
#   exhtml: <str(266)> <p>The <b>rose-breasted grosbeak</b> is a lar...
#   exrest: <str(217)> The rose-breasted grosbeak is a large, seed-e...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Rosebreas...
#   infobox: <dict(13)> name, image, image_caption, image2, image2_c...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 373189
#   parsetree: <str(42076)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Rose-breasted_grosbeak
#   url: https://en.wikipedia.org/wiki/Rose-breasted grosbeak
#   url_raw: https://en.wikipedia.org/wiki/Rose-breasted grosbeak?ac...
#   wikibase: Q839834
#   wikidata_url: https://www.wikidata.org/wiki/Q839834
#   wikitext: <str(33030)> {{speciesbox| name = Rose-breasted grosbe...
# }
# en.wikipedia.org (parse) Black-headed grosbeak
# en.wikipedia.org (imageinfo) File:Pheucticus melanocephalus -Cali...
# Black-headed grosbeak (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Pheucticu...
#   infobox: <dict(9)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 3112564
#   parsetree: <str(19443)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Black-headed grosbeak
#   wikibase: Q998547
#   wikidata_url: https://www.wikidata.org/wiki/Q998547
#   wikitext: <str(15183)> {{Use dmy dates|date=July 2013}}{{species...
# }
# en.wikipedia.org (restbase) /page/summary/Black-headed grosbeak
# Black-headed grosbeak (en) data
# {
#   description: species of bird
#   exhtml: <str(264)> <p>The <b>black-headed grosbeak</b> is a medi...
#   exrest: <str(250)> The black-headed grosbeak is a medium-sized, ...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Pheucticu...
#   infobox: <dict(9)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 3112564
#   parsetree: <str(19443)> <root><template><title>Use dmy dates</ti...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Black-headed_grosbeak
#   url: https://en.wikipedia.org/wiki/Black-headed grosbeak
#   url_raw: https://en.wikipedia.org/wiki/Black-headed grosbeak?act...
#   wikibase: Q998547
#   wikidata_url: https://www.wikidata.org/wiki/Q998547
#   wikitext: <str(15183)> {{Use dmy dates|date=July 2013}}{{species...
# }
# en.wikipedia.org (parse) Blue grosbeak
# en.wikipedia.org (imageinfo) File:Blue Grosbeak by Dan Pancamo.jpg
# Blue grosbeak (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Blue Gros...
#   infobox: <dict(11)> image, image_caption, image2, image2_caption...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 3112446
#   parsetree: <str(15844)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Blue grosbeak
#   wikibase: Q794337
#   wikidata_url: https://www.wikidata.org/wiki/Q794337
#   wikitext: <str(12070)> {{speciesbox| image = Blue Grosbeak by Da...
# }
# en.wikipedia.org (restbase) /page/summary/Blue grosbeak
# Blue grosbeak (en) data
# {
#   description: species of bird
#   exhtml: <str(195)> <p>The <b>blue grosbeak</b>, is a medium-size...
#   exrest: <str(181)> The blue grosbeak, is a medium-sized seed-eat...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Blue Gros...
#   infobox: <dict(11)> image, image_caption, image2, image2_caption...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 3112446
#   parsetree: <str(15844)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Blue_grosbeak
#   url: https://en.wikipedia.org/wiki/Blue grosbeak
#   url_raw: https://en.wikipedia.org/wiki/Blue grosbeak?action=raw
#   wikibase: Q794337
#   wikidata_url: https://www.wikidata.org/wiki/Q794337
#   wikitext: <str(12070)> {{speciesbox| image = Blue Grosbeak by Da...
# }
# en.wikipedia.org (parse) Lazuli bunting
# en.wikipedia.org (imageinfo) File:Lazuli Bunting.jpg
# Lazuli bunting (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Lazuli Bu...
#   infobox: <dict(7)> image, status, status_system, genus, species,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Passerina_...
#   pageid: 1158054
#   parsetree: <str(14214)> <root><template><title>Speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Lazuli bunting
#   wikibase: Q786964
#   wikidata_url: https://www.wikidata.org/wiki/Q786964
#   wikitext: <str(12203)> {{Speciesbox| image = Lazuli Bunting.jpg|...
# }
# en.wikipedia.org (restbase) /page/summary/Lazuli bunting
# Lazuli bunting (en) data
# {
#   description: species of bird
#   exhtml: <str(98)> <p>The <b>lazuli bunting</b> is a North Americ...
#   exrest: <str(84)> The lazuli bunting is a North American songbir...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Lazuli Bu...
#   infobox: <dict(7)> image, status, status_system, genus, species,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Passerina_...
#   pageid: 1158054
#   parsetree: <str(14214)> <root><template><title>Speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Lazuli_bunting
#   url: https://en.wikipedia.org/wiki/Lazuli bunting
#   url_raw: https://en.wikipedia.org/wiki/Lazuli bunting?action=raw
#   wikibase: Q786964
#   wikidata_url: https://www.wikidata.org/wiki/Q786964
#   wikitext: <str(12203)> {{Speciesbox| image = Lazuli Bunting.jpg|...
# }
# en.wikipedia.org (parse) Indigo bunting
# en.wikipedia.org (imageinfo) File:Passerina cyaneaAAP086CA.jpg
# Indigo bunting (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(10)> image, image_caption, status, status_system,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 374362
#   parsetree: <str(24002)> <root><template><title>speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Indigo bunting
#   wikibase: Q1049642
#   wikidata_url: https://www.wikidata.org/wiki/Q1049642
#   wikitext: <str(16719)> {{speciesbox| image = Passerina cyaneaAAP...
# }
# en.wikipedia.org (restbase) /page/summary/Indigo bunting
# Indigo bunting (en) data
# {
#   description: species of bird
#   exhtml: <str(498)> <p>The <b>indigo bunting</b> is a small seed-...
#   exrest: <str(484)> The indigo bunting is a small seed-eating bir...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(10)> image, image_caption, status, status_system,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 374362
#   parsetree: <str(24002)> <root><template><title>speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Indigo_bunting
#   url: https://en.wikipedia.org/wiki/Indigo bunting
#   url_raw: https://en.wikipedia.org/wiki/Indigo bunting?action=raw
#   wikibase: Q1049642
#   wikidata_url: https://www.wikidata.org/wiki/Q1049642
#   wikitext: <str(16719)> {{speciesbox| image = Passerina cyaneaAAP...
# }
# en.wikipedia.org (parse) Varied bunting
# en.wikipedia.org (imageinfo) File:Passerina versicolorAOP02CA.jpg
# Varied bunting (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(7)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Passerina_...
#   pageid: 3111713
#   parsetree: <str(6447)> <root><template><title>speciesbox</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Varied bunting
#   wikibase: Q934456
#   wikidata_url: https://www.wikidata.org/wiki/Q934456
#   wikitext: <str(4329)> {{speciesbox| status = LC| status_system =...
# }
# en.wikipedia.org (restbase) /page/summary/Varied bunting
# Varied bunting (en) data
# {
#   description: species of bird
#   exhtml: <str(95)> <p>The <b>varied bunting</b> is a species of s...
#   exrest: <str(81)> The varied bunting is a species of songbird in...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(7)> status, status_system, image, image_caption, ...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Passerina_...
#   pageid: 3111713
#   parsetree: <str(6447)> <root><template><title>speciesbox</title>...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Varied_bunting
#   url: https://en.wikipedia.org/wiki/Varied bunting
#   url_raw: https://en.wikipedia.org/wiki/Varied bunting?action=raw
#   wikibase: Q934456
#   wikidata_url: https://www.wikidata.org/wiki/Q934456
#   wikitext: <str(4329)> {{speciesbox| status = LC| status_system =...
# }
# en.wikipedia.org (parse) Painted bunting
# en.wikipedia.org (imageinfo) File:Passerina ciris-20090208.jpg
# Painted bunting (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(11)> status, status_system, image, image_caption,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 1995858
#   parsetree: <str(26225)> <root><template><title>Speciesbox</title...
#   requests: <list(2)> parse, imageinfo
#   title: Painted bunting
#   wikibase: Q932970
#   wikidata_url: https://www.wikidata.org/wiki/Q932970
#   wikitext: <str(18694)> {{Speciesbox| status = LC| status_system ...
# }
# en.wikipedia.org (restbase) /page/summary/Painted bunting
# Painted bunting (en) data
# {
#   description: species of bird
#   exhtml: <str(281)> <p>The <b>painted bunting</b> is a species of...
#   exrest: <str(267)> The painted bunting is a species of bird in t...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Passerina...
#   infobox: <dict(11)> status, status_system, image, image_caption,...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 1995858
#   parsetree: <str(26225)> <root><template><title>Speciesbox</title...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Painted_bunting
#   url: https://en.wikipedia.org/wiki/Painted bunting
#   url_raw: https://en.wikipedia.org/wiki/Painted bunting?action=raw
#   wikibase: Q932970
#   wikidata_url: https://www.wikidata.org/wiki/Q932970
#   wikitext: <str(18694)> {{Speciesbox| status = LC| status_system ...
# }
# en.wikipedia.org (parse) Dickcissel
# en.wikipedia.org (imageinfo) File:DickcisselA.jpg
# Dickcissel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dickcisse...
#   infobox: <dict(11)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Spiza_amer...
#   pageid: 476325
#   parsetree: <str(30627)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Dickcissel
#   wikibase: Q1210224
#   wikidata_url: https://www.wikidata.org/wiki/Q1210224
#   wikitext: <str(26876)> {{More citations needed|date=January 2011...
# }
# en.wikipedia.org (restbase) /page/summary/Dickcissel
# Dickcissel (en) data
# {
#   description: species of bird
#   exhtml: <str(210)> <p>The <b>dickcissel</b> is a small American ...
#   exrest: <str(182)> The dickcissel is a small American seed-eatin...
#   image: <list(3)> {'kind': 'parse-image', 'file': 'File:Dickcisse...
#   infobox: <dict(11)> name, image, image_caption, status, status_s...
#   iwlinks: <list(4)> https://commons.wikimedia.org/wiki/Spiza_amer...
#   pageid: 476325
#   parsetree: <str(30627)> <root><template><title>More citations ne...
#   requests: <list(3)> parse, imageinfo, restbase
#   title: Dickcissel
#   url: https://en.wikipedia.org/wiki/Dickcissel
#   url_raw: https://en.wikipedia.org/wiki/Dickcissel?action=raw
#   wikibase: Q1210224
#   wikidata_url: https://www.wikidata.org/wiki/Q1210224
#   wikitext: <str(26876)> {{More citations needed|date=January 2011...
# }
# en.wikipedia.org (parse) Portal:Birds
# Portal:Birds (en) data
# {
#   infobox: <dict(1)> noedit
#   iwlinks: <list(11)> https://commons.wikimedia.org/wiki/Special:S...
#   pageid: 10803401
#   parsetree: <str(97682)> <root><template><title>Portal maintenanc...
#   requests: <list(1)> parse
#   title: Portal:Birds
#   wikibase: Q4162252
#   wikidata_url: https://www.wikidata.org/wiki/Q4162252
#   wikitext: <str(37051)> {{Portal maintenance status|date=June 201...
# }
# en.wikipedia.org (restbase) /page/summary/Portal:Birds
# Portal:Birds (en) data
# {
#   description: Wikipedia's portal for exploring content related to...
#   exhtml:
#   exrest:
#   infobox: <dict(1)> noedit
#   iwlinks: <list(11)> https://commons.wikimedia.org/wiki/Special:S...
#   pageid: 10803401
#   parsetree: <str(97682)> <root><template><title>Portal maintenanc...
#   requests: <list(2)> parse, restbase
#   title: Portal:Birds
#   url: https://en.wikipedia.org/wiki/Portal:Birds
#   url_raw: https://en.wikipedia.org/wiki/Portal:Birds?action=raw
#   wikibase: Q4162252
#   wikidata_url: https://www.wikidata.org/wiki/Q4162252
#   wikitext: <str(37051)> {{Portal maintenance status|date=June 201...
# }
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-4ba92790f073> in <module>
#      44             url = restbase.data['url']
#      45
# ---> 46             kingdom, phylum, order, family = find_bird(url)
#      47
#      48             try:
#
# <ipython-input-2-7d81f2a1c350> in find_bird(request)
#      18                 m = m + 1
#      19
# ---> 20     return kingdom, phylum, order, family
#
# UnboundLocalError: local variable 'kingdom' referenced before assignment

# %%
bird_df['kingdom'] = bird_df['kingdom'].str.replace('\\n','')
bird_df['phylum'] = bird_df['phylum'].str.replace('\\n','')
bird_df['order'] = bird_df['order'].str.replace('\\n','')
bird_df['family'] = bird_df['family'].str.replace('\\n','')
bird_df
# Out:
#                             breed  \
# 0    Black-bellied whistling-duck
# 1          Fulvous whistling-duck
# 2                   Emperor goose
# 3                      Snow goose
# 4                    Ross's goose
# 5                   Greylag goose
# 6     Greater white-fronted goose
# 7                Taiga bean-goose
# 8               Tundra bean-goose
# 9               Pink-footed goose
# 10                  Brant (goose)
# 11                 Barnacle goose
# 12                 Cackling goose
# 13                   Canada goose
# 14                      Mute swan
# 15                 Trumpeter swan
# 16                    Tundra swan
# 17                   Whooper swan
# 18                 Ruddy shelduck
# 19                Common shelduck
# 20                      Wood duck
# 21                    Baikal teal
# 22                       Garganey
# 23               Blue-winged teal
# 24                  Cinnamon teal
# 25              Northern shoveler
# 26                        Gadwall
# 27                  Falcated duck
# 28                Eurasian wigeon
# 29                American wigeon
# ..                            ...
# 656        Chestnut-sided warbler
# 657             Blackpoll warbler
# 658   Black-throated blue warbler
# 659                  Palm warbler
# 660                  Pine warbler
# 661         Yellow-rumped warbler
# 662       Yellow-throated warbler
# 663               Prairie warbler
# 664               Grace's warbler
# 665   Black-throated grey warbler
# 666            Townsend's warbler
# 667                Hermit warbler
# 668  Black-throated green warbler
# 669                Canada warbler
# 670              Wilson's warbler
# 671              Painted redstart
# 672               Hepatic tanager
# 673                Summer tanager
# 674               Scarlet tanager
# 675               Western tanager
# 676             Northern cardinal
# 677                   Pyrrhuloxia
# 678        Rose-breasted grosbeak
# 679         Black-headed grosbeak
# 680                 Blue grosbeak
# 681                Lazuli bunting
# 682                Indigo bunting
# 683                Varied bunting
# 684               Painted bunting
# 685                    Dickcissel
#
#                                                summary  \
# 0    The black-bellied whistling-duck (Dendrocygna ...
# 1    The fulvous whistling duck or fulvous tree duc...
# 2    The emperor goose (Anser canagicus), also know...
# 3    The snow goose (Anser caerulescens), consistin...
# 4    Ross's goose (Anser rossii) is a white goose w...
# 5    The greylag goose (Anser anser) is a species o...
# 6    The greater white-fronted goose (Anser albifro...
# 7    The taiga bean goose (Anser fabalis) is a goos...
# 8    The  tundra bean goose (Anser serrirostris) is...
# 9    The pink-footed goose (Anser brachyrhynchus) i...
# 10   The brant, or brent goose (Branta bernicla), i...
# 11   The barnacle goose (Branta leucopsis) belongs ...
# 12   The cackling goose (Branta hutchinsii) is a No...
# 13   The Canada goose (Branta canadensis) is a larg...
# 14   The mute swan (Cygnus olor) is a species of sw...
# 15   The trumpeter swan (Cygnus buccinator) is a sp...
# 16   The tundra swan (Cygnus columbianus) is a smal...
# 17   The whooper swan (Cygnus cygnus), also as the ...
# 18   The ruddy shelduck (Tadorna ferruginea), known...
# 19   The common shelduck (Tadorna tadorna) is a wat...
# 20   The wood duck or Carolina duck (Aix sponsa) is...
# 21   The Baikal teal (Sibirionetta formosa), also c...
# 22   The garganey (Spatula querquedula) is a small ...
# 23   The blue-winged teal (Spatula discors) is a sp...
# 24   The cinnamon teal (Spatula cyanoptera) is a sp...
# 25   The northern shoveler (; Spatula clypeata), kn...
# 26   The gadwall (Mareca strepera) is a common and ...
# 27   The falcated duck or falcated teal (Mareca fal...
# 28   The Eurasian wigeon, also known as widgeon (Ma...
# 29   The American wigeon (Mareca americana), also c...
# ..                                                 ...
# 656  The chestnut-sided warbler (Setophaga pensylva...
# 657  The blackpoll warbler (Setophaga striata) is a...
# 658  The black-throated blue warbler (Setophaga cae...
# 659  The palm warbler (Setophaga palmarum) is a sma...
# 660  The pine warbler (Setophaga pinus) is a small ...
# 661  The yellow-rumped warbler (Setophaga coronata)...
# 662  The yellow-throated warbler (Setophaga dominic...
# 663  The prairie warbler (Setophaga discolor) is a ...
# 664  Grace's warbler (Setophaga graciae) is a small...
# 665  The black-throated gray warbler or black-throa...
# 666  Townsend's warbler (Setophaga townsendi) is a ...
# 667  The hermit warbler (Setophaga occidentalis) is...
# 668  The black-throated green warbler (Setophaga vi...
# 669  The Canada warbler (Cardellina canadensis) is ...
# 670  The Wilson's warbler (Cardellina pusilla) is a...
# 671  The painted whitestart or painted redstart (My...
# 672  The hepatic tanager (Piranga flava) is a mediu...
# 673  The summer tanager (Piranga rubra) is a medium...
# 674  The scarlet tanager (Piranga olivacea) is a me...
# 675  The western tanager (Piranga ludoviciana), is ...
# 676  The northern cardinal (Cardinalis cardinalis) ...
# 677  The pyrrhuloxia or desert cardinal (Cardinalis...
# 678  The rose-breasted grosbeak (Pheucticus ludovic...
# 679  The black-headed grosbeak (Pheucticus melanoce...
# 680  The blue grosbeak (Passerina caerulea), is a m...
# 681  The lazuli bunting (Passerina amoena) is a Nor...
# 682  The indigo bunting (Passerina cyanea) is a sma...
# 683  The varied bunting (Passerina versicolor) is a...
# 684  The painted bunting (Passerina ciris) is a spe...
# 685  The dickcissel (Spiza americana) is a small Am...
#
#                                                  image conservation_status  \
# 0    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 1    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 2    https://upload.wikimedia.org/wikipedia/commons...     Near Threatened
# 3    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 4    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 5    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 6    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 7    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 8    https://upload.wikimedia.org/wikipedia/commons...                None
# 9    https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 10   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 11   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 12   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 13   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 14   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 15   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 16   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 17   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 18   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 19   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 20   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 21   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 22   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 23   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 24   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 25   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 26   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 27   https://upload.wikimedia.org/wikipedia/commons...     Near Threatened
# 28   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 29   https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# ..                                                 ...                 ...
# 656  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 657  https://upload.wikimedia.org/wikipedia/commons...     Near Threatened
# 658  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 659  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 660  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 661  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 662  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 663  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 664  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 665  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 666  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 667  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 668  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 669  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 670  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 671  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 672  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 673  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 674  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 675  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 676  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 677  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 678  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 679  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 680  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 681  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 682  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 683  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 684  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
# 685  https://upload.wikimedia.org/wikipedia/commons...       Least Concern
#
#       kingdom    phylum          order        family  \
# 0    Animalia  Chordata   Anseriformes      Anatidae
# 1    Animalia  Chordata   Anseriformes      Anatidae
# 2    Animalia  Chordata   Anseriformes      Anatidae
# 3    Animalia  Chordata   Anseriformes      Anatidae
# 4    Animalia  Chordata   Anseriformes      Anatidae
# 5    Animalia  Chordata   Anseriformes      Anatidae
# 6    Animalia  Chordata   Anseriformes      Anatidae
# 7    Animalia  Chordata   Anseriformes      Anatidae
# 8    Animalia  Chordata   Anseriformes      Anatidae
# 9    Animalia  Chordata   Anseriformes      Anatidae
# 10   Animalia  Chordata   Anseriformes      Anatidae
# 11   Animalia  Chordata   Anseriformes      Anatidae
# 12   Animalia  Chordata   Anseriformes      Anatidae
# 13   Animalia  Chordata   Anseriformes      Anatidae
# 14   Animalia  Chordata   Anseriformes      Anatidae
# 15   Animalia  Chordata   Anseriformes      Anatidae
# 16   Animalia  Chordata   Anseriformes      Anatidae
# 17   Animalia  Chordata   Anseriformes      Anatidae
# 18   Animalia  Chordata   Anseriformes      Anatidae
# 19   Animalia  Chordata   Anseriformes      Anatidae
# 20   Animalia  Chordata   Anseriformes      Anatidae
# 21   Animalia  Chordata   Anseriformes      Anatidae
# 22   Animalia  Chordata   Anseriformes      Anatidae
# 23   Animalia  Chordata   Anseriformes      Anatidae
# 24   Animalia  Chordata   Anseriformes      Anatidae
# 25   Animalia  Chordata   Anseriformes      Anatidae
# 26   Animalia  Chordata   Anseriformes      Anatidae
# 27   Animalia  Chordata   Anseriformes      Anatidae
# 28   Animalia  Chordata   Anseriformes      Anatidae
# 29   Animalia  Chordata   Anseriformes      Anatidae
# ..        ...       ...            ...           ...
# 656  Animalia  Chordata  Passeriformes     Parulidae
# 657  Animalia  Chordata  Passeriformes     Parulidae
# 658  Animalia  Chordata  Passeriformes     Parulidae
# 659  Animalia  Chordata  Passeriformes     Parulidae
# 660  Animalia  Chordata  Passeriformes     Parulidae
# 661  Animalia  Chordata  Passeriformes     Parulidae
# 662  Animalia  Chordata  Passeriformes     Parulidae
# 663  Animalia  Chordata  Passeriformes     Parulidae
# 664  Animalia  Chordata  Passeriformes     Parulidae
# 665  Animalia  Chordata  Passeriformes     Parulidae
# 666  Animalia  Chordata  Passeriformes     Parulidae
# 667  Animalia  Chordata  Passeriformes     Parulidae
# 668  Animalia  Chordata  Passeriformes     Parulidae
# 669  Animalia  Chordata  Passeriformes     Parulidae
# 670  Animalia  Chordata  Passeriformes     Parulidae
# 671  Animalia  Chordata  Passeriformes     Parulidae
# 672  Animalia  Chordata  Passeriformes  Cardinalidae
# 673  Animalia  Chordata  Passeriformes  Cardinalidae
# 674  Animalia  Chordata  Passeriformes  Cardinalidae
# 675  Animalia  Chordata  Passeriformes  Cardinalidae
# 676  Animalia  Chordata  Passeriformes  Cardinalidae
# 677  Animalia  Chordata  Passeriformes  Cardinalidae
# 678  Animalia  Chordata  Passeriformes  Cardinalidae
# 679  Animalia  Chordata  Passeriformes  Cardinalidae
# 680  Animalia  Chordata  Passeriformes  Cardinalidae
# 681  Animalia  Chordata  Passeriformes  Cardinalidae
# 682  Animalia  Chordata  Passeriformes  Cardinalidae
# 683  Animalia  Chordata  Passeriformes  Cardinalidae
# 684  Animalia  Chordata  Passeriformes  Cardinalidae
# 685  Animalia  Chordata  Passeriformes  Cardinalidae
#
#                  binomial_name
# 0       Dendrocygna autumnalis
# 1          Dendrocygna bicolor
# 2              Anser canagicus
# 3           Anser caerulescens
# 4                 Anser rossii
# 5                  Anser anser
# 6              Anser albifrons
# 7                Anser fabalis
# 8           Anser serrirostris
# 9         Anser brachyrhynchus
# 10             Branta bernicla
# 11            Branta leucopsis
# 12           Branta hutchinsii
# 13           Branta canadensis
# 14                 Cygnus olor
# 15           Cygnus buccinator
# 16          Cygnus columbianus
# 17               Cygnus cygnus
# 18          Tadorna ferruginea
# 19             Tadorna tadorna
# 20                  Aix sponsa
# 21        Sibirionetta formosa
# 22         Spatula querquedula
# 23             Spatula discors
# 24          Spatula cyanoptera
# 25            Spatula clypeata
# 26             Mareca strepera
# 27              Mareca falcata
# 28             Mareca penelope
# 29            Mareca americana
# ..                         ...
# 656     Setophaga pensylvanica
# 657          Setophaga striata
# 658     Setophaga caerulescens
# 659         Setophaga palmarum
# 660            Setophaga pinus
# 661         Setophaga coronata
# 662         Setophaga dominica
# 663         Setophaga discolor
# 664          Setophaga graciae
# 665       Setophaga nigrescens
# 666        Setophaga townsendi
# 667     Setophaga occidentalis
# 668           Setophaga virens
# 669      Cardellina canadensis
# 670         Cardellina pusilla
# 671           Myioborus pictus
# 672              Piranga flava
# 673              Piranga rubra
# 674           Piranga olivacea
# 675        Piranga ludoviciana
# 676      Cardinalis cardinalis
# 677        Cardinalis sinuatus
# 678    Pheucticus ludovicianus
# 679  Pheucticus melanocephalus
# 680         Passerina caerulea
# 681           Passerina amoena
# 682           Passerina cyanea
# 683       Passerina versicolor
# 684            Passerina ciris
# 685            Spiza americana
#
# [686 rows x 9 columns]

# %%
bird_df = bird_df.drop_duplicates(subset = 'breed')
bird_df.to_csv('bird.csv',index = True, header = True)

# %%
#cat
cat_df = pd.DataFrame(columns=['breed', 'summary', 'image', 'other_names', 'nicknames', 'origin'])

html = requests.get('https://en.wikipedia.org/wiki/List_of_cat_breeds')

#turn the HTML into a beautiful soup text object
b = BeautifulSoup(html.text, 'lxml')

# get to the table on the page
for i in b.find_all(name='table', class_='wikitable sortable'):
    for j in i.find_all(name='tr'):        
        #get the summary of each breed
        for k in j.find_all(name='th'):
            # get within that cell to just get the words
            for link in k.find_all('a', href=True):
                if(re.match('^#', link['href'])):
                    continue
                else:
                    breed = j.find('a')['title']
                    page = wptools.page(breed)
                    parse = page.get_parse()
                    
                    try:
                        other_names = parse.data['infobox']['altname']
                    except:
                        other_names = None
                        
                    try:
                        nicknames = parse.data['infobox']['nickname']
                    except:
                        nicknames = None
                    
                    try:
                        origin = parse.data['infobox']['country']
                    except:
                        origin = None
                        
                    try:
                        image = parse.data['image'][0]['url']
                    except:
                        image = 'https://user-images.githubusercontent.com/24848110/33519396-7e56363c-d79d-11e7-969b-09782f5ccbab.png'
                    
                    summary = wikipedia.WikipediaPage(breed).summary

                    cat_df = cat_df.append({'breed':breed, 'summary': summary, 'image':image,
                                           'other_names': other_names, 'nicknames': nicknames,
                                            'origin': origin}, ignore_index = True)
# Out:
# en.wikipedia.org (parse) Abyssinian cat
# en.wikipedia.org (imageinfo) File:Gustav chocolate.jpg
# Abyssinian cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Gustav ch...
#   infobox: <dict(9)> name, image, imagecaption, country, fifestd, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Abyssinian
#   pageid: 30875080
#   parsetree: <str(14105)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Abyssinian cat
#   wikibase: Q7955
#   wikidata_url: https://www.wikidata.org/wiki/Q7955
#   wikitext: <str(11290)> {{Infobox Catbreed|name=Abyssinian|image=...
# }
# en.wikipedia.org (parse) Aegean cat
# en.wikipedia.org (imageinfo) File:Aegean cat.jpg
# Aegean cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Aegean ca...
#   infobox: <dict(5)> name, image, imagecaption, country, note
#   pageid: 14293772
#   parsetree: <str(5116)> <root><template><title>More citations nee...
#   requests: <list(2)> parse, imageinfo
#   title: Aegean cat
#   wikibase: Q7957
#   wikidata_url: https://www.wikidata.org/wiki/Q7957
#   wikitext: <str(3668)> {{More citations needed|date=May 2013}}{{O...
# }
# en.wikipedia.org (parse) American Curl
# en.wikipedia.org (imageinfo) File:American curl 2.jpg
# American Curl (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:American ...
#   infobox: <dict(10)> name, image, country, ticastd, cfastd, aaces...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 70025
#   parsetree: <str(9058)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: American Curl
#   wikibase: Q7960
#   wikidata_url: https://www.wikidata.org/wiki/Q7960
#   wikitext: <str(6291)> {{Infobox Catbreed| name=American Curl| im...
# }
# en.wikipedia.org (parse) American Bobtail
# en.wikipedia.org (imageinfo) File:American bobtail 2.jpg
# American Bobtail (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:American ...
#   infobox: <dict(10)> name, image, image_width, country, cfastd, t...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 148839
#   parsetree: <str(11338)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: American Bobtail
#   wikibase: Q7874
#   wikidata_url: https://www.wikidata.org/wiki/Q7874
#   wikitext: <str(8689)> {{Infobox Catbreed| name=American Bobtail|...
# }
# en.wikipedia.org (parse) American Shorthair
# en.wikipedia.org (imageinfo) File:14 years old american shorthair.jpg
# American Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:14 years ...
#   infobox: <dict(9)> name, altname, image, country, cfastd, acfast...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 638469
#   parsetree: <str(7179)> <root><template><title>Infobox cat breed<...
#   requests: <list(2)> parse, imageinfo
#   title: American Shorthair
#   wikibase: Q7962
#   wikidata_url: https://www.wikidata.org/wiki/Q7962
#   wikitext: <str(5569)> {{Infobox cat breed| name=American Shortha...
# }
# en.wikipedia.org (parse) American Wirehair
# en.wikipedia.org (imageinfo) File:American Wirehair - CFF cat sho...
# American Wirehair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:American ...
#   infobox: <dict(9)> name, image, imagecaption, country, ticastd, ...
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Special:Search...
#   pageid: 2328963
#   parsetree: <str(7213)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: American Wirehair
#   wikibase: Q7964
#   wikidata_url: https://www.wikidata.org/wiki/Q7964
#   wikitext: <str(5292)> {{Infobox Catbreed| name=American Wirehair...
# }
# en.wikipedia.org (parse) Cyprus cat
# en.wikipedia.org (imageinfo) File:CyprusShorthair.jpg
# Cyprus cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:CyprusSho...
#   infobox: <dict(8)> name, image, imagecaption, altname, country, ...
#   pageid: 34524418
#   parsetree: <str(22836)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Cyprus cat
#   wikibase: Q5200515
#   wikidata_url: https://www.wikidata.org/wiki/Q5200515
#   wikitext: <str(17636)> {{More citations needed|date=January 2011...
# }
# en.wikipedia.org (parse) Arabian Mau
# en.wikipedia.org (imageinfo) File:Bex Arabian Mau.jpg
# Arabian Mau (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bex Arabi...
#   infobox: <dict(5)> name, image, imagecaption, country, wcfstd
#   pageid: 35809078
#   parsetree: <str(7844)> <root><template><title>Infobox cat breed<...
#   requests: <list(2)> parse, imageinfo
#   title: Arabian Mau
#   wikibase: Q7970
#   wikidata_url: https://www.wikidata.org/wiki/Q7970
#   wikitext: <str(6097)> {{Infobox cat breed| name = Arabian Mau| i...
# }
# en.wikipedia.org (parse) Australian Mist
# en.wikipedia.org (imageinfo) File:Australian Mist.jpg
# Australian Mist (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Australia...
#   infobox: <dict(6)> name, image, imagecaption, altname, country, ...
#   pageid: 63889
#   parsetree: <str(7246)> <root><template><title>More citations nee...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Mist
#   wikibase: Q7989
#   wikidata_url: https://www.wikidata.org/wiki/Q7989
#   wikitext: <str(5298)> {{More citations needed|date=March 2008}}{...
# }
# en.wikipedia.org (parse) Asian cat
# en.wikipedia.org (imageinfo) File:BrownVarientAsianCat.JPG
# Asian cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:BrownVari...
#   infobox: <dict(4)> image, name, altname, country
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 11444751
#   parsetree: <str(6205)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Asian cat
#   wikibase: Q7974
#   wikidata_url: https://www.wikidata.org/wiki/Q7974
#   wikitext: <str(4890)> {{Refimprove|date=June 2009}}{{Infobox Cat...
# }
# en.wikipedia.org (parse) Asian Semi-longhair
# en.wikipedia.org (imageinfo) File:Tiffanie at cat show.jpg
# Asian Semi-longhair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tiffanie ...
#   infobox: <dict(6)> name, image, imagecaption, altname, country, ...
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Special:Search...
#   pageid: 3413387
#   parsetree: <str(4605)> <root><template><title>Infobox cat breed<...
#   requests: <list(2)> parse, imageinfo
#   title: Asian Semi-longhair
#   wikibase: Q7986
#   wikidata_url: https://www.wikidata.org/wiki/Q7986
#   wikitext: <str(2986)> {{Infobox cat breed|name = Asian Semi-long...
# }
# en.wikipedia.org (parse) Balinese cat
# en.wikipedia.org (imageinfo) File:Old-Style Balinese Cat.png
# Balinese cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Old-Style...
#   infobox: <dict(12)> name, image, imagecaption, altname, country,...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 42964218
#   parsetree: <str(19960)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Balinese cat
#   wikibase: Q9665
#   wikidata_url: https://www.wikidata.org/wiki/Q9665
#   wikitext: <str(16497)> {{Use dmy dates|date=June 2011}}{{Infobox...
# }
# en.wikipedia.org (parse) Bambino cat
# Bambino cat (en) data
# {
#   pageid: 32389924
#   parsetree: <str(8492)> <root><template><title>refimprove</title>...
#   requests: <list(1)> parse
#   title: Bambino cat
#   wikibase: Q9667
#   wikidata_url: https://www.wikidata.org/wiki/Q9667
#   wikitext: <str(7126)> {{refimprove|date=December 2018}}The '''Ba...
# }
# en.wikipedia.org (parse) Bengal cat
# en.wikipedia.org (imageinfo) File:Paintedcats Red Star standing.jpg
# Bengal cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Paintedca...
#   infobox: <dict(15)> name, image, imagecaption, stock, country, f...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Bengal_(ca...
#   pageid: 63064
#   parsetree: <str(38157)> <root><template><title>Close paraphrasin...
#   requests: <list(2)> parse, imageinfo
#   title: Bengal cat
#   wikibase: Q42583
#   wikidata_url: https://www.wikidata.org/wiki/Q42583
#   wikitext: <str(30554)> {{Close paraphrasing|date=May 2019}}{{Inf...
# }
# en.wikipedia.org (parse) Birman
# en.wikipedia.org (imageinfo) File:Birmanstrofe.jpg
# Birman (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Birmanstr...
#   infobox: <dict(11)> name, image, imagecaption, altname, country,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Birman
#   pageid: 146048
#   parsetree: <str(14017)> <root><template><title>other</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Birman
#   wikibase: Q42563
#   wikidata_url: https://www.wikidata.org/wiki/Q42563
#   wikitext: <str(11290)> {{other|Birman (disambiguation)}}{{Use dm...
# }
# en.wikipedia.org (parse) Bombay cat
# en.wikipedia.org (imageinfo) File:Close up of a black domestic cat.jpg
# Bombay cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Close up ...
#   infobox: <dict(9)> name, image, imagecaption, ticastd, aacestd, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 638492
#   parsetree: <str(7595)> <root><template><title>Use dmy dates</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Bombay cat
#   wikibase: Q42566
#   wikidata_url: https://www.wikidata.org/wiki/Q42566
#   wikitext: <str(5369)> {{Use dmy dates|date=June 2011}}{{Infobox ...
# }
# en.wikipedia.org (parse) Brazilian Shorthair
# en.wikipedia.org (imageinfo) File:Gato pelo curto brasileiro.JPG
# Brazilian Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Gato pelo...
#   infobox: <dict(3)> name, image, country
#   pageid: 19031302
#   parsetree: <str(10114)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Brazilian Shorthair
#   wikibase: Q29280
#   wikidata_url: https://www.wikidata.org/wiki/Q29280
#   wikitext: <str(7127)> {{Use dmy dates|date=June 2011}}{{Unrefere...
# }
# en.wikipedia.org (parse) British Longhair
# en.wikipedia.org (imageinfo) File:British Longhair - Blue Bicolor.jpg
# British Longhair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:British L...
#   infobox: <dict(4)> image, origin, ticastd, ffestd
#   pageid: 15178017
#   parsetree: <str(10515)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: British Longhair
#   wikibase: Q29268
#   wikidata_url: https://www.wikidata.org/wiki/Q29268
#   wikitext: <str(6846)> {{More citations needed|date=March 2013}}{...
# }
# en.wikipedia.org (parse) British Shorthair
# en.wikipedia.org (imageinfo) File:Britishblue.jpg
# British Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Britishbl...
#   infobox: <dict(14)> name, scientific name, image, imagecaption, ...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 45323
#   parsetree: <str(21939)> <root><template><title>Multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: British Shorthair
#   wikibase: Q29273
#   wikidata_url: https://www.wikidata.org/wiki/Q29273
#   wikitext: <str(16944)> {{Multiple issues|{{weasel|date=May 2015}...
# }
# en.wikipedia.org (parse) British Longhair
# en.wikipedia.org (imageinfo) File:British Longhair - Blue Bicolor.jpg
# British Longhair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:British L...
#   infobox: <dict(4)> image, origin, ticastd, ffestd
#   pageid: 15178017
#   parsetree: <str(10515)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: British Longhair
#   wikibase: Q29268
#   wikidata_url: https://www.wikidata.org/wiki/Q29268
#   wikitext: <str(6846)> {{More citations needed|date=March 2013}}{...
# }
# en.wikipedia.org (parse) Burmese cat
# en.wikipedia.org (imageinfo) File:Male Chocolate Burmese Cat.jpg
# Burmese cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Male Choc...
#   infobox: <dict(12)> name, image, imagecaption, country, acfstd, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 261787
#   parsetree: <str(28802)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Burmese cat
#   wikibase: Q42573
#   wikidata_url: https://www.wikidata.org/wiki/Q42573
#   wikitext: <str(21974)> {{Use dmy dates|date=July 2019}}{{hatnote...
# }
# en.wikipedia.org (parse) Burmilla
# en.wikipedia.org (imageinfo) File:Male Burmilla cat.jpeg
# Burmilla (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Male Burm...
#   infobox: <dict(8)> name, image, imagecaption, altname, country, ...
#   pageid: 1259546
#   parsetree: <str(8913)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: Burmilla
#   wikibase: Q29258
#   wikidata_url: https://www.wikidata.org/wiki/Q29258
#   wikitext: <str(7214)> {{Infobox Catbreed| name = Burmilla| image...
# }
# en.wikipedia.org (parse) California Spangled
# en.wikipedia.org (imageinfo) File:Star Spangled Cat.jpg
# California Spangled (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Star Span...
#   infobox: <dict(5)> name, altname, image, country, ticastd
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 615214
#   parsetree: <str(7878)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: California Spangled
#   wikibase: Q42556
#   wikidata_url: https://www.wikidata.org/wiki/Q42556
#   wikitext: <str(5700)> {{Infobox Catbreed| name = California Span...
# }
# en.wikipedia.org (parse) Chantilly-Tiffany
# Chantilly-Tiffany (en) data
# {
#   image: <list(0)>
#   infobox: <dict(5)> name, image, imagecaption, altname, country
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 1516202
#   parsetree: <str(12347)> <root><template><title>More footnotes</t...
#   requests: <list(1)> parse
#   title: Chantilly-Tiffany
#   wikibase: Q392693
#   wikidata_url: https://www.wikidata.org/wiki/Q392693
#   wikitext: <str(9649)> {{More footnotes|date=May 2014}} {{Infobox...
# }
# en.wikipedia.org (parse) Chartreux
# en.wikipedia.org (imageinfo) File:IC Blue Melody Flipper CHA male...
# Chartreux (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:IC Blue M...
#   infobox: <dict(8)> name, image, country, cfastd, acfastd, ccastd...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 638548
#   parsetree: <str(9627)> <root><template><title>Other uses</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Chartreux
#   wikibase: Q42588
#   wikidata_url: https://www.wikidata.org/wiki/Q42588
#   wikitext: <str(7643)> {{Other uses|Chartreuse (disambiguation){{...
# }
# en.wikipedia.org (parse) Chausie
# en.wikipedia.org (imageinfo) File:ChausieA.jpg
# Chausie (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:ChausieA....
#   infobox: <dict(5)> name, image, imagecaption, ticastd, x
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 1022343
#   parsetree: <str(18278)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Chausie
#   wikibase: Q42546
#   wikidata_url: https://www.wikidata.org/wiki/Q42546
#   wikitext: <str(14910)> {{Infobox Catbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Cheetoh cat
# en.wikipedia.org (imageinfo) File:Paintedcats Red Star standing.jpg
# Bengal cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Paintedca...
#   infobox: <dict(15)> name, image, imagecaption, stock, country, f...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Bengal_(ca...
#   pageid: 63064
#   parsetree: <str(38157)> <root><template><title>Close paraphrasin...
#   requests: <list(2)> parse, imageinfo
#   title: Bengal cat
#   wikibase: Q42583
#   wikidata_url: https://www.wikidata.org/wiki/Q42583
#   wikitext: <str(30554)> {{Close paraphrasing|date=May 2019}}{{Inf...
# }
# en.wikipedia.org (parse) Colorpoint Shorthair
# Colorpoint Shorthair (en) data
# {
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/Special:Search...
#   pageid: 2570560
#   parsetree: <str(8821)> <root><template><title>More citations nee...
#   requests: <list(1)> parse
#   title: Colorpoint Shorthair
#   wikibase: Q4115865
#   wikidata_url: https://www.wikidata.org/wiki/Q4115865
#   wikitext: <str(7213)> {{More citations needed|date=November 2018...
# }
# en.wikipedia.org (parse) Cornish Rex
# en.wikipedia.org (imageinfo) File:BebopsLilacPrince.JPG
# Cornish Rex (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:BebopsLil...
#   infobox: <dict(12)> name, image, altnames, country, gccfstd, aac...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 63258
#   parsetree: <str(9283)> <root><template><title>refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Cornish Rex
#   wikibase: Q42559
#   wikidata_url: https://www.wikidata.org/wiki/Q42559
#   wikitext: <str(7538)> {{refimprove|date=November 2011}}{{Infobox...
# }
# en.wikipedia.org (parse) Cymric cat
# en.wikipedia.org (imageinfo) File:Cymric - Norwegian forest cat p...
# Cymric cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Cymric - ...
#   infobox: <dict(19)> name, image, altname, country, cfastd, fifes...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:C...
#   pageid: 145675
#   parsetree: <str(24594)> <root><template><title>Use Canadian Engl...
#   requests: <list(2)> parse, imageinfo
#   title: Cymric cat
#   wikibase: Q42578
#   wikidata_url: https://www.wikidata.org/wiki/Q42578
#   wikitext: <str(19077)> {{Use Canadian English|note=Typically tha...
# }
# en.wikipedia.org (parse) Cyprus cat
# en.wikipedia.org (imageinfo) File:CyprusShorthair.jpg
# Cyprus cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:CyprusSho...
#   infobox: <dict(8)> name, image, imagecaption, altname, country, ...
#   pageid: 34524418
#   parsetree: <str(22836)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Cyprus cat
#   wikibase: Q5200515
#   wikidata_url: https://www.wikidata.org/wiki/Q5200515
#   wikitext: <str(17636)> {{More citations needed|date=January 2011...
# }
# en.wikipedia.org (parse) Devon Rex
# en.wikipedia.org (imageinfo) File:Devon Rex Cassini.jpeg
# Devon Rex (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Devon Rex...
#   infobox: <dict(11)> name, image, country, gccfstd, aacestd, cfas...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:D...
#   pageid: 146038
#   parsetree: <str(7515)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: Devon Rex
#   wikibase: Q42570
#   wikidata_url: https://www.wikidata.org/wiki/Q42570
#   wikitext: <str(5746)> {{Infobox Catbreed| name = Devon Rex| imag...
# }
# en.wikipedia.org (parse) Donskoy cat
# en.wikipedia.org (imageinfo) File:DSX World Premior RU*Don Xuk's ...
# Donskoy cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': "File:DSX World...
#   infobox: <dict(6)> name, image, altname, country, ticastd, fifestd
#   pageid: 1065489
#   parsetree: <str(8549)> <root><template><title>Infobox Catbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Donskoy cat
#   wikibase: Q7303
#   wikidata_url: https://www.wikidata.org/wiki/Q7303
#   wikitext: <str(6191)> {{Infobox Catbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Dragon Li
# en.wikipedia.org (imageinfo) File:Dragon Li - Li Hua Mau1.jpg
# Dragon Li (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dragon Li...
#   infobox: <dict(3)> image, imagecaption, altname
#   pageid: 19997444
#   parsetree: <str(12160)> <root><template><title>Infobox cat breed...
#   requests: <list(2)> parse, imageinfo
#   title: Dragon Li
#   wikibase: Q7334
#   wikidata_url: https://www.wikidata.org/wiki/Q7334
#   wikitext: <str(7508)> {{Infobox cat breed <!-- Put article text ...
# }
# en.wikipedia.org (parse) List of experimental cat breeds
# List of experimental cat breeds (en) data
# {
#   pageid: 28660394
#   parsetree: <str(28328)> <root><template><title>See also</title><...
#   requests: <list(1)> parse
#   title: List of experimental cat breeds
#   wikibase: Q16000183
#   wikidata_url: https://www.wikidata.org/wiki/Q16000183
#   wikitext: <str(22667)> {{See also|List of cat breeds}}[[File:Hig...
# }
# en.wikipedia.org (parse) Egyptian Mau
# en.wikipedia.org (imageinfo) File:Egyptian Mau Bronze.jpg
# Egyptian Mau (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Egyptian ...
#   infobox: <dict(11)> name, image, image_width, imagecaption, coun...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 386875
#   parsetree: <str(18060)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Egyptian Mau
#   wikibase: Q7295
#   wikidata_url: https://www.wikidata.org/wiki/Q7295
#   wikitext: <str(11960)> {{Infobox Catbreed| name = Egyptian Mau| ...
# }
# en.wikipedia.org (parse) European Shorthair
# en.wikipedia.org (imageinfo) File:European shorthair procumbent Q...
# European Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:European ...
#   infobox: <dict(4)> name, image, country, fifestd
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 1158095
#   parsetree: <str(9358)> <root><template><title>Infobox Catbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: European Shorthair
#   wikibase: Q20793
#   wikidata_url: https://www.wikidata.org/wiki/Q20793
#   wikitext: <str(7841)> {{Infobox Catbreed| name = European Shorth...
# }
# en.wikipedia.org (parse) Exotic Shorthair
# en.wikipedia.org (imageinfo) File:Brown Exotic Shorthair Kitten.jpg
# Exotic Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Brown Exo...
#   infobox: <dict(8)> name, image, imagecaption, country, aacestd, ...
#   pageid: 71025
#   parsetree: <str(11527)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Exotic Shorthair
#   wikibase: Q42555
#   wikidata_url: https://www.wikidata.org/wiki/Q42555
#   wikitext: <str(9803)> {{Infobox Catbreed| name = Exotic Shorthai...
# }
# en.wikipedia.org (parse) Foldex cat
# Foldex cat (en) data
# {
#   pageid: 48575141
#   parsetree: <str(2020)> <root>[[File:Cachorro de Gato FoldEx (&qu...
#   requests: <list(1)> parse
#   title: Foldex cat
#   wikibase: Q21075654
#   wikidata_url: https://www.wikidata.org/wiki/Q21075654
#   wikitext: <str(1505)> [[File:Cachorro de Gato FoldEx ("Belisario...
# }
# en.wikipedia.org (parse) German Rex
# en.wikipedia.org (imageinfo) File:German rex harry (cropped).jpg
# German Rex (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:German re...
#   infobox: <dict(5)> name, image, nickname, country, fifestd
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:G...
#   pageid: 5495150
#   parsetree: <str(9221)> <root><template lineStart="1"><title>Refi...
#   requests: <list(2)> parse, imageinfo
#   title: German Rex
#   wikibase: Q42551
#   wikidata_url: https://www.wikidata.org/wiki/Q42551
#   wikitext: <str(7212)> {{Refimprove|date=October 2008}}{{Infobox ...
# }
# en.wikipedia.org (parse) Havana Brown
# en.wikipedia.org (imageinfo) File:Havana Brown.jpg
# Havana Brown (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Havana Br...
#   infobox: <dict(11)> name, image, altname, nickname, country, cfa...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:H...
#   pageid: 565399
#   parsetree: <str(12453)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Havana Brown
#   wikibase: Q42645
#   wikidata_url: https://www.wikidata.org/wiki/Q42645
#   wikitext: <str(10471)> {{About|a breed of cat|Australian DJ and ...
# }
# en.wikipedia.org (parse) Highlander cat
# en.wikipedia.org (imageinfo) File:Highlander-7.jpg
# Highlander cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Highlande...
#   infobox: <dict(9)> name, image, altname, country, stock, x, tica...
#   pageid: 38724655
#   parsetree: <str(10625)> <root><template><title>Redirect</title><...
#   requests: <list(2)> parse, imageinfo
#   title: Highlander cat
#   wikibase: Q25471053
#   wikidata_url: https://www.wikidata.org/wiki/Q25471053
#   wikitext: <str(6826)> {{Redirect|Highlander (cat)|other breeds k...
# }
# en.wikipedia.org (parse) Himalayan cat
# en.wikipedia.org (imageinfo) File:Himalayan CAT.jpg
# Himalayan cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Himalayan...
#   infobox: <dict(12)> name, image, imagecaption, altname, nickname...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:H...
#   pageid: 146031
#   parsetree: <str(19308)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Himalayan cat
#   wikibase: Q42959
#   wikidata_url: https://www.wikidata.org/wiki/Q42959
#   wikitext: <str(16093)> {{Infobox Catbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Japanese Bobtail
# en.wikipedia.org (imageinfo) File:JapaneseBobtailBlueEyedMi-ke.JPG
# Japanese Bobtail (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:JapaneseB...
#   infobox: <dict(5)> name, image, imagecaption, cfastd, ticastd
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:J...
#   pageid: 148843
#   parsetree: <str(18170)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Japanese Bobtail
#   wikibase: Q42673
#   wikidata_url: https://www.wikidata.org/wiki/Q42673
#   wikitext: <str(14489)> {{about|the cat|the squid|Japanese Bobtai...
# }
# en.wikipedia.org (parse) Javanese cat
# en.wikipedia.org (imageinfo) File:Javanese cat.jpg
# Javanese cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Javanese ...
#   infobox: <dict(7)> name, image, imagecaption, altname, country, ...
#   pageid: 638898
#   parsetree: <str(12458)> <root><template><title>Use American Engl...
#   requests: <list(2)> parse, imageinfo
#   title: Javanese cat
#   wikibase: Q42661
#   wikidata_url: https://www.wikidata.org/wiki/Q42661
#   wikitext: <str(9276)> {{Use American English|date=July 2018}}{{U...
# }
# en.wikipedia.org (parse) Khao Manee
# en.wikipedia.org (imageinfo) File:Khaomanee cat.jpg
# Khao Manee (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Khaomanee...
#   infobox: <dict(9)> name, image, imagecaption, altname, nickname,...
#   pageid: 24030657
#   parsetree: <str(11585)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Khao Manee
#   wikibase: Q42700
#   wikidata_url: https://www.wikidata.org/wiki/Q42700
#   wikitext: <str(9129)> {{Refimprove|date=October 2009}}{{Infobox ...
# }
# en.wikipedia.org (parse) Korat
# en.wikipedia.org (imageinfo) File:Face et profil du korat.JPG
# Korat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Face et p...
#   infobox: <dict(11)> name, image, altname, country, cfastd, fifes...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:K...
#   pageid: 298906
#   parsetree: <str(13333)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Korat
#   wikibase: Q42691
#   wikidata_url: https://www.wikidata.org/wiki/Q42691
#   wikitext: <str(10441)> {{About|the cat breed||Khorat (disambigua...
# }
# en.wikipedia.org (parse) Korean Bobtail
# Natural bobtail (en) data
# {
#   pageid: 2780327
#   parsetree: <str(6247)> <root>A '''natural bobtail''' is an anima...
#   requests: <list(1)> parse
#   title: Natural bobtail
#   wikibase: Q6980652
#   wikidata_url: https://www.wikidata.org/wiki/Q6980652
#   wikitext: <str(5487)> A '''natural bobtail''' is an animal's tai...
# }
# en.wikipedia.org (parse) Kurilian Bobtail
# en.wikipedia.org (imageinfo) File:Kurilian bobtail.JPG
# Kurilian Bobtail (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Kurilian ...
#   infobox: <dict(14)> name, image, imagecaption, altname, country,...
#   pageid: 22279493
#   parsetree: <str(14564)> <root><template><title>Distinguish</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Kurilian Bobtail
#   wikibase: Q7338
#   wikidata_url: https://www.wikidata.org/wiki/Q7338
#   wikitext: <str(8699)> {{Distinguish|Karelian Bobtail<!--a.k.a. K...
# }
# en.wikipedia.org (parse) LaPerm
# en.wikipedia.org (imageinfo) File:Laperm LH blacktortie white.jpg
# LaPerm (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Laperm LH...
#   infobox: <dict(9)> name, image, imagecaption, country, cfastd, f...
#   pageid: 5387760
#   parsetree: <str(20203)> <root><template><title>Multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: LaPerm
#   wikibase: Q42639
#   wikidata_url: https://www.wikidata.org/wiki/Q42639
#   wikitext: <str(16515)> {{Multiple issues|{{cleanup|reason=articl...
# }
# en.wikipedia.org (parse) Lykoi
# en.wikipedia.org (imageinfo) File:8-month-old male Lykoi.jpg
# Lykoi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:8-month-o...
#   infobox: <dict(6)> name, nickname, country, image, ticastd, note
#   pageid: 42287415
#   parsetree: <str(6262)> <root><template><title>Infobox cat breed ...
#   requests: <list(2)> parse, imageinfo
#   title: Lykoi
#   wikibase: Q16913794
#   wikidata_url: https://www.wikidata.org/wiki/Q16913794
#   wikitext: <str(4584)> {{Infobox cat breed |name=Lykoi |altname= ...
# }
# en.wikipedia.org (parse) Maine Coon
# en.wikipedia.org (imageinfo) File:Maine Coon cat by Tomitheos.JPG
# Maine Coon (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Maine Coo...
#   infobox: <dict(12)> name, image, imagecaption, altname, nickname...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Maine_Coon...
#   pageid: 70024
#   parsetree: <str(38062)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Maine Coon
#   wikibase: Q42659
#   wikidata_url: https://www.wikidata.org/wiki/Q42659
#   wikitext: <str(30315)> {{Use dmy dates|date=May 2016}}{{Infobox ...
# }
# en.wikipedia.org (parse) Manx cat
# en.wikipedia.org (imageinfo) File:Manx cat by Karen Weaver.jpg
# Manx cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Manx cat ...
#   infobox: <dict(22)> name, image, imagecaption, altname, nickname...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Manx
#   pageid: 145672
#   parsetree: <str(97905)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Manx cat
#   wikibase: Q42675
#   wikidata_url: https://www.wikidata.org/wiki/Q42675
#   wikitext: <str(72119)> {{Use dmy dates|date=June 2011}}{{Infobox...
# }
# en.wikipedia.org (parse) Minskin
# en.wikipedia.org (imageinfo) File:Minskin Kitten Female blue tabb...
# Minskin (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Minskin K...
#   infobox: <dict(5)> name, image, imagecaption, country, ticastd
#   pageid: 26130075
#   parsetree: <str(4945)> <root><template><title>Infobox Catbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Minskin
#   wikibase: Q3039052
#   wikidata_url: https://www.wikidata.org/wiki/Q3039052
#   wikitext: <str(3489)> {{Infobox Catbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Munchkin cat
# en.wikipedia.org (imageinfo) File:Longhairedmunchkin.jpg
# Munchkin cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Longhaire...
#   infobox: <dict(6)> name, image, imagecaption, country, aacestd, ...
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/viable
#   pageid: 145780
#   parsetree: <str(24008)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Munchkin cat
#   wikibase: Q686698
#   wikidata_url: https://www.wikidata.org/wiki/Q686698
#   wikitext: <str(18887)> {{Infobox Catbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Nebelung
# en.wikipedia.org (imageinfo) File:Nebelung Cat at 10.JPG
# Nebelung (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Nebelung ...
#   infobox: <dict(8)> name, image, imagecaption, altname, country, ...
#   pageid: 173764
#   parsetree: <str(9440)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Nebelung
#   wikibase: Q42647
#   wikidata_url: https://www.wikidata.org/wiki/Q42647
#   wikitext: <str(7553)> {{Refimprove|date=December 2012}}{{Infobox...
# }
# en.wikipedia.org (parse) Minuet cat
# Minuet cat (en) data
# {
#   pageid: 32745073
#   parsetree: <str(5051)> <root><template><title>One source</title>...
#   requests: <list(1)> parse
#   title: Minuet cat
#   wikibase: Q6965006
#   wikidata_url: https://www.wikidata.org/wiki/Q6965006
#   wikitext: <str(4343)> {{One source|date= February 2012}}The '''N...
# }
# en.wikipedia.org (parse) Norwegian Forest cat
# Norwegian Forest cat (en) data
# {
#   infobox: <dict(9)> altname, country, ticastd, fifestd, cfastd, a...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:N...
#   pageid: 173757
#   parsetree: <str(24387)> <root><template><title>good article</tit...
#   requests: <list(1)> parse
#   title: Norwegian Forest cat
#   wikibase: Q42667
#   wikidata_url: https://www.wikidata.org/wiki/Q42667
#   wikitext: <str(18714)> {{good article}}{{Infobox cat breed  |nam...
# }
# en.wikipedia.org (parse) Ocicat
# en.wikipedia.org (imageinfo) File:Tawny ocicat kitten with cinnam...
# Ocicat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tawny oci...
#   infobox: <dict(10)> name, image, country, cfastd, fifestd, ticas...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Ocicat
#   pageid: 145785
#   parsetree: <str(9205)> <root><template><title>Infobox Catbreed<c...
#   requests: <list(2)> parse, imageinfo
#   title: Ocicat
#   wikibase: Q42685
#   wikidata_url: https://www.wikidata.org/wiki/Q42685
#   wikitext: <str(7061)> {{Infobox Catbreed<!-- Put article text AF...
# }
# en.wikipedia.org (parse) Ojos Azules
# Ojos Azules (en) data
# {
#   infobox: <dict(3)> name, country, ticastd
#   pageid: 1136544
#   parsetree: <str(6638)> <root><template><title>for</title><part><...
#   requests: <list(1)> parse
#   title: Ojos Azules
#   wikibase: Q42640
#   wikidata_url: https://www.wikidata.org/wiki/Q42640
#   wikitext: <str(5012)> {{for|the Latin American song|Ojos azules ...
# }
# en.wikipedia.org (parse) Oregon Rex
# Oregon Rex (en) data
# {
#   pageid: 20582289
#   parsetree: <str(4133)> <root>The '''Oregon Rex''' was one of sev...
#   requests: <list(1)> parse
#   title: Oregon Rex
#   wikibase: Q42676
#   wikidata_url: https://www.wikidata.org/wiki/Q42676
#   wikitext: <str(3334)> The '''Oregon Rex''' was one of several [[...
# }
# en.wikipedia.org (parse) Oriental Bicolor
# Oriental bicolour (en) data
# {
#   pageid: 13807127
#   parsetree: <str(5919)> <root><template><title>No footnotes</titl...
#   requests: <list(1)> parse
#   title: Oriental bicolour
#   wikibase: Q7102323
#   wikidata_url: https://www.wikidata.org/wiki/Q7102323
#   wikitext: <str(5561)> {{No footnotes|date=June 2014}} <!-- The f...
# }
# en.wikipedia.org (parse) Oriental Shorthair
# en.wikipedia.org (imageinfo) File:Oriental Shorthair Blue Eyed Wh...
# Oriental Shorthair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Oriental ...
#   infobox: <dict(16)> name, image, imagecaption, image2, imagecapt...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:O...
#   pageid: 639613
#   parsetree: <str(16649)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Oriental Shorthair
#   wikibase: Q42696
#   wikidata_url: https://www.wikidata.org/wiki/Q42696
#   wikitext: <str(12618)> {{Refimprove|date=February 2012}}{{Infobo...
# }
# en.wikipedia.org (parse) Oriental Longhair
# en.wikipedia.org (imageinfo) File:OLH-GIP Divan Cesar.jpg
# Oriental Longhair (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:OLH-GIP D...
#   infobox: <dict(9)> name, image, imagecaption, altname, cfastd, f...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:O...
#   pageid: 2569354
#   parsetree: <str(5861)> <root><template><title>infobox cat breed<...
#   requests: <list(2)> parse, imageinfo
#   title: Oriental Longhair
#   wikibase: Q2099338
#   wikidata_url: https://www.wikidata.org/wiki/Q2099338
#   wikitext: <str(4467)> {{infobox cat breed| name          = Orien...
# }
# en.wikipedia.org (parse) Persian cat
# en.wikipedia.org (imageinfo) File:White Persian Cat.jpg
# Persian cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:White Per...
#   infobox: <dict(15)> name, image, altname, country, cfastd, fifes...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 33876998
#   parsetree: <str(71742)> <root><template><title>Use mdy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Persian cat
#   wikibase: Q42610
#   wikidata_url: https://www.wikidata.org/wiki/Q42610
#   wikitext: <str(60078)> {{Use mdy dates|date=January 2018}}{{Info...
# }
# en.wikipedia.org (parse) Traditional Persian
# en.wikipedia.org (imageinfo) File:SnowyandHazy.jpg
# Traditional Persian (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:SnowyandH...
#   infobox: <dict(7)> name, image, imagecaption, altname, country, ...
#   pageid: 30456458
#   parsetree: <str(12023)> <root><template><title>Infobox Catbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Traditional Persian
#   wikibase: Q7832303
#   wikidata_url: https://www.wikidata.org/wiki/Q7832303
#   wikitext: <str(10052)> {{Infobox Catbreed | name= Traditional Pe...
# }
# en.wikipedia.org (parse) Peterbald
# en.wikipedia.org (imageinfo) File:Peterbald male Shango by Irina ...
# Peterbald (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Peterbald...
#   infobox: <dict(4)> name, image, image_caption, country
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 2769391
#   parsetree: <str(5415)> <root><template lineStart="1"><title>unre...
#   requests: <list(2)> parse, imageinfo
#   title: Peterbald
#   wikibase: Q42663
#   wikidata_url: https://www.wikidata.org/wiki/Q42663
#   wikitext: <str(4420)> {{unreferenced|date=March 2014}}<!-- Put a...
# }
# en.wikipedia.org (parse) Pixie-bob
# en.wikipedia.org (imageinfo) File:Uptoyou duFarWestwithBePacific2.jpg
# Pixie-bob (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Uptoyou d...
#   infobox: <dict(7)> name, image, imagecaption, country, ticastd, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:P...
#   pageid: 963131
#   parsetree: <str(11676)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Pixie-bob
#   wikibase: Q42693
#   wikidata_url: https://www.wikidata.org/wiki/Q42693
#   wikitext: <str(8934)> {{Refimprove|date=March 2008}}{{Infobox ca...
# }
# en.wikipedia.org (parse) Raas cat
# Raas cat (en) data
# {
#   infobox: <dict(3)> name, altname, country
#   pageid: 43569735
#   parsetree: <str(2277)> <root><template><title>Infobox cat breed ...
#   requests: <list(1)> parse
#   title: Raas cat
#   wikibase: Q17517549
#   wikidata_url: https://www.wikidata.org/wiki/Q17517549
#   wikitext: <str(1266)> {{Infobox cat breed  |name         = Raas ...
# }
# en.wikipedia.org (parse) Ragamuffin cat
# en.wikipedia.org (imageinfo) File:20050922AmarilloRes.jpg
# Ragamuffin cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:20050922A...
#   infobox: <dict(5)> name, image, country, cfastd, acfastd
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 3055080
#   parsetree: <str(10270)> <root><template><title>Other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: Ragamuffin cat
#   wikibase: Q42637
#   wikidata_url: https://www.wikidata.org/wiki/Q42637
#   wikitext: <str(7796)> {{Other uses|Ragamuffin (disambiguation){{...
# }
# en.wikipedia.org (parse) Ragdoll
# en.wikipedia.org (imageinfo) File:Ragdoll from Gatil Ragbelas.jpg
# Ragdoll (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ragdoll f...
#   infobox: <dict(4)> name, image, country, cfastd
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:R...
#   pageid: 610191
#   parsetree: <str(22235)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Ragdoll
#   wikibase: Q42688
#   wikidata_url: https://www.wikidata.org/wiki/Q42688
#   wikitext: <str(17194)> {{About|the cat breed|the toy|Rag doll|ot...
# }
# en.wikipedia.org (parse) Russian Blue
# en.wikipedia.org (imageinfo) File:Russian blue.jpg
# Russian Blue (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Russian b...
#   infobox: <dict(14)> name, image, imagecaption, altname, country,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Russian_Blue
#   pageid: 144792
#   parsetree: <str(14941)> <root><template lineStart="1"><title>Inf...
#   requests: <list(2)> parse, imageinfo
#   title: Russian Blue
#   wikibase: Q42654
#   wikidata_url: https://www.wikidata.org/wiki/Q42654
#   wikitext: <str(12047)> {{Infobox Catbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Russian White, Black, and Tabby
# Russian White, Black, and Tabby (en) data
# {
#   pageid: 12556065
#   parsetree: <str(5232)> <root>The '''Russian White, Russian Black...
#   requests: <list(1)> parse
#   title: Russian White, Black, and Tabby
#   wikibase: Q13035968
#   wikidata_url: https://www.wikidata.org/wiki/Q13035968
#   wikitext: <str(4739)> The '''Russian White, Russian Black,''' an...
# }
# en.wikipedia.org (parse) Savannah cat
# en.wikipedia.org (imageinfo) File:Savannah Cat portrait.jpg
# Savannah cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Savannah ...
#   infobox: <dict(7)> name, image, country, cfastd, ticastd, note, x
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 1954032
#   parsetree: <str(27633)> <root><template><title>Redirect</title><...
#   requests: <list(2)> parse, imageinfo
#   title: Savannah cat
#   wikibase: Q42670
#   wikidata_url: https://www.wikidata.org/wiki/Q42670
#   wikitext: <str(23048)> {{Redirect|Ashera|the ancient middle-east...
# }
# en.wikipedia.org (parse) Scottish Fold
# en.wikipedia.org (imageinfo) File:Adult Scottish Fold.jpg
# Scottish Fold (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Adult Sco...
#   infobox: <dict(11)> name, image, imagecaption, altname, nickname...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 145684
#   parsetree: <str(27507)> <root><template><title>Redirect</title><...
#   requests: <list(2)> parse, imageinfo
#   title: Scottish Fold
#   wikibase: Q42636
#   wikidata_url: https://www.wikidata.org/wiki/Q42636
#   wikitext: <str(22181)> {{Redirect|Highland Straight|the long-hai...
# }
# en.wikipedia.org (parse) Selkirk Rex
# en.wikipedia.org (imageinfo) File:PolloSelkirkRex.jpg
# Selkirk Rex (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:PolloSelk...
#   infobox: <dict(3)> name, image, country
#   pageid: 64022
#   parsetree: <str(6857)> <root><template><title>refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Selkirk Rex
#   wikibase: Q42642
#   wikidata_url: https://www.wikidata.org/wiki/Q42642
#   wikitext: <str(5934)> {{refimprove|date=January 2012}}{{Infobox ...
# }
# en.wikipedia.org (parse) Serengeti cat
# en.wikipedia.org (imageinfo) File:Serengetimalecat.jpg
# Serengeti cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Serengeti...
#   infobox: <dict(6)> name, image, imagecaption, country, ticastd, x
#   pageid: 2851028
#   parsetree: <str(5512)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Serengeti cat
#   wikibase: Q7308
#   wikidata_url: https://www.wikidata.org/wiki/Q7308
#   wikitext: <str(3732)> {{Refimprove|date=January 2010}}{{Infobox ...
# }
# en.wikipedia.org (parse) Siamese cat
# en.wikipedia.org (imageinfo) File:Siamese Cat p.jpg
# Siamese cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Siamese C...
#   infobox: <dict(11)> name, image, imagecaption, image2, country, ...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 63087
#   parsetree: <str(36285)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Siamese cat
#   wikibase: Q42604
#   wikidata_url: https://www.wikidata.org/wiki/Q42604
#   wikitext: <str(31425)> {{About|the modern, long-faced breed|the ...
# }
# en.wikipedia.org (parse) Siberian cat
# en.wikipedia.org (imageinfo) File:Siberian Forest Cat.jpg
# Siberian cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Siberian ...
#   infobox: <dict(12)> name, image, altname, country, cfastd, fifes...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 639735
#   parsetree: <str(21588)> <root><template><title>Infobox cat breed...
#   requests: <list(2)> parse, imageinfo
#   title: Siberian cat
#   wikibase: Q42630
#   wikidata_url: https://www.wikidata.org/wiki/Q42630
#   wikitext: <str(17143)> {{Infobox cat breed|name          = Siber...
# }
# en.wikipedia.org (parse) Singapura cat
# en.wikipedia.org (imageinfo) File:Singapura Cats.jpg
# Singapura cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Singapura...
#   infobox: <dict(10)> name, image, imagecaption, altname, country,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 639747
#   parsetree: <str(19076)> <root><template><title>Infobox Catbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Singapura cat
#   wikibase: Q42679
#   wikidata_url: https://www.wikidata.org/wiki/Q42679
#   wikitext: <str(14457)> {{Infobox Catbreed <!-- Put article text ...
# }
# en.wikipedia.org (parse) Snowshoe cat
# en.wikipedia.org (imageinfo) File:Snowshoe Siamese Kitten.jpg
# Snowshoe cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Snowshoe ...
#   infobox: <dict(8)> name, image, country, aacestd, acfastd, ticas...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 799673
#   parsetree: <str(20110)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Snowshoe cat
#   wikibase: Q42633
#   wikidata_url: https://www.wikidata.org/wiki/Q42633
#   wikitext: <str(15954)> {{Infobox Catbreed| name = Snowshoe Cat| ...
# }
# en.wikipedia.org (parse) Sokoke
# Sokoke (en) data
# {
#   infobox: <dict(8)> name, imagecaption, altname, country, stock, ...
#   iwlinks: <list(1)> https://en.wiktionary.org/wiki/en:stifle
#   pageid: 1034110
#   parsetree: <str(21804)> <root><template><title>Refimprove</title...
#   requests: <list(1)> parse
#   title: Sokoke
#   wikibase: Q2075066
#   wikidata_url: https://www.wikidata.org/wiki/Q2075066
#   wikitext: <str(16987)> {{Refimprove|date=March 2008}}{{Infobox C...
# }
# en.wikipedia.org (parse) Somali cat
# en.wikipedia.org (imageinfo) File:Blue Somali kitten age 3 months.jpg
# Somali cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Blue Soma...
#   infobox: <dict(12)> name, image, imagecaption, nickname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 148091
#   parsetree: <str(12748)> <root><template><title>original research...
#   requests: <list(2)> parse, imageinfo
#   title: Somali cat
#   wikibase: Q42715
#   wikidata_url: https://www.wikidata.org/wiki/Q42715
#   wikitext: <str(9348)> {{original research|date=June 2016}}{{Info...
# }
# en.wikipedia.org (parse) Sphynx cat
# en.wikipedia.org (imageinfo) File:Sphinx2 July 2006.jpg
# Sphynx cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sphinx2 J...
#   infobox: <dict(10)> name, image, country, aacestd, cfastd, acfas...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 64150
#   parsetree: <str(24554)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Sphynx cat
#   wikibase: Q42712
#   wikidata_url: https://www.wikidata.org/wiki/Q42712
#   wikitext: <str(20149)> {{about|the breed of cat|the legendary cr...
# }
# en.wikipedia.org (parse) Suphalak
# en.wikipedia.org (imageinfo) File:Suphalak Female in Thailand nam...
# Suphalak (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Suphalak ...
#   infobox: <dict(8)> name, image, imagecaption, altname, country, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:S...
#   pageid: 46232331
#   parsetree: <str(14998)> <root><template><title>Original research...
#   requests: <list(2)> parse, imageinfo
#   title: Suphalak
#   wikibase: Q21002394
#   wikidata_url: https://www.wikidata.org/wiki/Q21002394
#   wikitext: <str(12704)> {{Original research|date=January 2019|rea...
# }
# en.wikipedia.org (parse) Thai cat
# en.wikipedia.org (imageinfo) File:PhaithaiChic Thai cat.jpg
# Thai cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:PhaithaiC...
#   infobox: <dict(12)> name, image, imagecaption, altname, nickname...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 12150640
#   parsetree: <str(19309)> <root><template><title>dablink</title><p...
#   requests: <list(2)> parse, imageinfo
#   title: Thai cat
#   wikibase: Q42732
#   wikidata_url: https://www.wikidata.org/wiki/Q42732
#   wikitext: <str(13646)> {{dablink|This page is about the old-styl...
# }
# en.wikipedia.org (parse) Korat
# en.wikipedia.org (imageinfo) File:Face et profil du korat.JPG
# Korat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Face et p...
#   infobox: <dict(11)> name, image, altname, country, cfastd, fifes...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:K...
#   pageid: 298906
#   parsetree: <str(13333)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Korat
#   wikibase: Q42691
#   wikidata_url: https://www.wikidata.org/wiki/Q42691
#   wikitext: <str(10441)> {{About|the cat breed||Khorat (disambigua...
# }
# en.wikipedia.org (parse) Tonkinese cat
# en.wikipedia.org (imageinfo) File:Tonkinese Cat - Leo.jpg
# Tonkinese cat (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tonkinese...
#   infobox: <dict(11)> name, image, imagecaption, nickname, country...
#   pageid: 580880
#   parsetree: <str(13790)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Tonkinese cat
#   wikibase: Q42726
#   wikidata_url: https://www.wikidata.org/wiki/Q42726
#   wikitext: <str(10549)> {{Refimprove|date=April 2016}}{{Infobox C...
# }
# en.wikipedia.org (parse) Toyger
# en.wikipedia.org (imageinfo) File:Toyger - Cornish Rex presentati...
# Toyger (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Toyger - ...
#   infobox: <dict(3)> name, image, ticastd
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Toyger
#   pageid: 2884695
#   parsetree: <str(9439)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Toyger
#   wikibase: Q7323
#   wikidata_url: https://www.wikidata.org/wiki/Q7323
#   wikitext: <str(7277)> {{Refimprove|date=March 2008}}{{Infobox ca...
# }
# en.wikipedia.org (parse) Turkish Angora
# en.wikipedia.org (imageinfo) File:Angora turc blanc 2.jpg
# Turkish Angora (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Angora tu...
#   infobox: <dict(10)> name, image, imagecaption, altname, country,...
#   pageid: 639754
#   parsetree: <str(19200)> <root><template><title>Infobox Catbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Turkish Angora
#   wikibase: Q42720
#   wikidata_url: https://www.wikidata.org/wiki/Q42720
#   wikitext: <str(15645)> {{Infobox Catbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Turkish Van
# en.wikipedia.org (imageinfo) File:Push van cat.jpg
# Turkish Van (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Push van ...
#   infobox: <dict(12)> name, image, imagecaption, altname, country,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 69704
#   parsetree: <str(23823)> <root><template><title>Distinguish</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Turkish Van
#   wikibase: Q42724
#   wikidata_url: https://www.wikidata.org/wiki/Q42724
#   wikitext: <str(16256)> {{Distinguish|Van cat|Turkish Angora|}}{{...
# }
# en.wikipedia.org (parse) Ukrainian Levkoy
# en.wikipedia.org (imageinfo) File:Ukrainian Levkoy cat.jpg
# Ukrainian Levkoy (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ukrainian...
#   infobox: <dict(3)> name, image, country
#   pageid: 17353018
#   parsetree: <str(8138)> <root><comment>&lt;!-- {{Under constructi...
#   requests: <list(2)> parse, imageinfo
#   title: Ukrainian Levkoy
#   wikibase: Q2642315
#   wikidata_url: https://www.wikidata.org/wiki/Q2642315
#   wikitext: <str(6045)> <!-- {{Under construction|date=May 2008}} ...
# }
# en.wikipedia.org (parse) York Chocolate
# en.wikipedia.org (imageinfo) File:York Chocolate.jpg
# York Chocolate (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:York Choc...
#   infobox: <dict(8)> name, image, altname, country, wcfstd, ffestd...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:Y...
#   pageid: 63895
#   parsetree: <str(10937)> <root><template><title>refimprove </titl...
#   requests: <list(2)> parse, imageinfo
#   title: York Chocolate
#   wikibase: Q2166017
#   wikidata_url: https://www.wikidata.org/wiki/Q2166017
#   wikitext: <str(7612)> {{refimprove |date=November 2012}}{{Infobo...
# }

# %%
cat_df = cat_df.drop_duplicates(subset='breed')
#cat_reset = cat_df.set_index('breed')
cat_df.to_csv('cat.csv', index = True, header = True)
#cat_reset.to_json('cat.json',orient='table')

# %%
cat_df

# %%
dog_df = pd.DataFrame(columns=['breed', 'summary', 'image','other_names','nicknames','origin','weight','height',
                              'coat','color','lifespan'])

html = requests.get('https://en.wikipedia.org/wiki/List_of_dog_breeds')

#turn the HTML into a beautiful soup text object
b = BeautifulSoup(html.text, 'lxml')

# get to the table on the page
for i in b.find_all(name='table', class_='wikitable sortable'):
    for j in i.find_all(name='tr'):        
        if(j.find('a') == None):
            continue
        else:
            breed = j.find('a')['title']
            page = wptools.page(breed)
            parse = page.get_parse()
            
            try:
                other_names = parse.data['infobox']['altname']
            except:
                other_names = None
            
            try:
                nicknames = parse.data['infobox']['nickname']
            except:
                nicknames = None
            
            try:
                origin = parse.data['infobox']['country']
            except:
                origin = None
                
            #some have male and/or female weight/height
            #because we only have a single column for weight, I'm only going 
            #to take the male weight if offered
            try:
                weight = parse.data['infobox']['weight']
            except:
                try:
                    weight = parse.data['infobox']['maleweight']
                except:
                    weight = None
            
            try:
                height = parse.data['infobox']['height']
            except:
                try:
                    height = parse.data['infobox']['maleheight']
                except:
                    height = None
            try:
                coat = parse.data['infobox']['coat']
            except:
                coat = None
            
            try:
                color = parse.data['infobox']['color']
            except:
                color = None
            
            try:
                lifespan = parse.data['infobox']['life_span']
            except:
                lifespan = None
            
            try:
                image = parse.data['image'][0]['url']
            except:
                image = 'https://user-images.githubusercontent.com/24848110/33519396-7e56363c-d79d-11e7-969b-09782f5ccbab.png'
            
            summary = wikipedia.WikipediaPage(breed).summary
            
            dog_df = dog_df.append({'breed':breed, 'summary': summary, 'image': image, 'other_names':other_names,
                                    'nicknames': nicknames, 'origin': origin, 'weight': weight,
                                    'height': height, 'coat': coat, 'color': color, 'lifespan': lifespan},
                                   ignore_index = True)
# Out:
# en.wikipedia.org (parse) Fédération Cynologique Internationale
# en.wikipedia.org (imageinfo) File:Fédération Cynologique Internat...
# Fédération Cynologique Internationale (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Fédératio...
#   infobox: <dict(10)> name, image, abbreviation, motto, formation,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:F...
#   pageid: 352258
#   parsetree: <str(14724)> <root><template><title>Primary sources</...
#   requests: <list(2)> parse, imageinfo
#   title: Fédération Cynologique Internationale
#   wikibase: Q38603
#   wikidata_url: https://www.wikidata.org/wiki/Q38603
#   wikitext: <str(9290)> {{Primary sources|date=December 2018}}{{in...
# }
# en.wikipedia.org (parse) Affenpinscher
# en.wikipedia.org (imageinfo) File:Affenpinscher.jpg
# Affenpinscher (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Affenpins...
#   infobox: <dict(29)> name, image, image_alt, image_caption, nickn...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 273885
#   parsetree: <str(18253)> <root><comment>&lt;!-- Wikipedia:WikiPro...
#   requests: <list(2)> parse, imageinfo
#   title: Affenpinscher
#   wikibase: Q7254
#   wikidata_url: https://www.wikidata.org/wiki/Q7254
#   wikitext: <str(12155)> <!-- Wikipedia:WikiProject Dog breeds/Tem...
# }
# en.wikipedia.org (parse) Afghan Hound
# en.wikipedia.org (imageinfo) File:Afghane.jpg
# Afghan Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Afghane.j...
#   infobox: <dict(27)> image, image_caption, name, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 2835
#   parsetree: <str(33589)> <root><template><title>Merge from</title...
#   requests: <list(2)> parse, imageinfo
#   title: Afghan Hound
#   wikibase: Q21080
#   wikidata_url: https://www.wikidata.org/wiki/Q21080
#   wikitext: <str(26830)> {{Merge from|Tazy|discuss=Wikipedia talk:...
# }
# en.wikipedia.org (parse) Kuchi dog
# Kuchi dog (en) data
# {
#   image: <list(0)>
#   infobox: <dict(6)> name, image, image_caption, nickname, altname...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:K...
#   pageid: 6865209
#   parsetree: <str(15824)> <root><template><title>Multiple issues</...
#   requests: <list(1)> parse
#   title: Kuchi dog
#   wikibase: Q4353411
#   wikidata_url: https://www.wikidata.org/wiki/Q4353411
#   wikitext: <str(13029)> {{Multiple issues|{{refimprove|date=March...
# }
# en.wikipedia.org (parse) Aidi
# en.wikipedia.org (imageinfo) File:Aidi.jpg
# Aidi (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Aidi.jpg'...
#   infobox: <dict(19)> name, image, image_alt, image_caption, altna...
#   pageid: 273903
#   parsetree: <str(11764)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Aidi
#   wikibase: Q37904
#   wikidata_url: https://www.wikidata.org/wiki/Q37904
#   wikitext: <str(6633)> {{About|the dog breed}}{{Infobox dog breed...
# }
# en.wikipedia.org (parse) Airedale Terrier
# en.wikipedia.org (imageinfo) File:Airedale Terrier.jpg
# Airedale Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Airedale ...
#   infobox: <dict(31)> name, image, image_caption, country, altname...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 175765
#   parsetree: <str(44956)> <root><template><title>Multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: Airedale Terrier
#   wikibase: Q37617
#   wikidata_url: https://www.wikidata.org/wiki/Q37617
#   wikitext: <str(32085)> {{Multiple issues|{{refimprove|date=Febru...
# }
# en.wikipedia.org (parse) Akbash
# en.wikipedia.org (imageinfo) File:Akbash Dog male 2016.jpg
# Akbash (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Akbash Do...
#   infobox: <dict(17)> name, image, image_alt, altname, country, ma...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Akbash
#   pageid: 815156
#   parsetree: <str(17737)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Akbash
#   wikibase: Q38175
#   wikidata_url: https://www.wikidata.org/wiki/Q38175
#   wikitext: <str(11911)> {{short description|Turkish breed of dog}...
# }
# en.wikipedia.org (parse) Akita (dog)
# en.wikipedia.org (imageinfo) File:Akita_Inu_dog.jpg
# Akita (dog) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Akita_Inu...
#   infobox: <dict(35)> name, altname, image, country, collapse_stan...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 59064
#   parsetree: <str(67598)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Akita (dog)
#   wikibase: Q29164
#   wikidata_url: https://www.wikidata.org/wiki/Q29164
#   wikitext: <str(50739)> {{Infobox dog breed<!-- Put article text ...
# }
# en.wikipedia.org (parse) Alano Español
# en.wikipedia.org (imageinfo) File:Alano-espanol-0003.jpg
# Alano Español (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alano-esp...
#   infobox: <dict(12)> image, name, altname, nickname, country, wei...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Alano_Espa...
#   pageid: 2501581
#   parsetree: <str(11596)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Alano Español
#   wikibase: Q37690
#   wikidata_url: https://www.wikidata.org/wiki/Q37690
#   wikitext: <str(8466)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Alapaha Blue Blood Bulldog
# en.wikipedia.org (imageinfo) File:Alapaha Blue-Blood Bulldog.jpg
# Alapaha Blue Blood Bulldog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alapaha B...
#   infobox: <dict(6)> country, altname, name, image, life_span, lit...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 59805304
#   parsetree: <str(4871)> <root><template><title>Infobox Dogbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: Alapaha Blue Blood Bulldog
#   wikibase: Q37489
#   wikidata_url: https://www.wikidata.org/wiki/Q37489
#   wikitext: <str(3239)> {{Infobox Dogbreed|country = {{US}}|image_...
# }
# en.wikipedia.org (parse) Alaskan husky
# en.wikipedia.org (imageinfo) File: Idol swingley.jpg
# Alaskan husky (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File: Idol swi...
#   infobox: <dict(9)> image, image_caption, name, country, maleweig...
#   pageid: 273870
#   parsetree: <str(10248)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Alaskan husky
#   wikibase: Q21205
#   wikidata_url: https://www.wikidata.org/wiki/Q21205
#   wikitext: <str(8043)> {{More citations needed|date=July 2019}}{{...
# }
# en.wikipedia.org (parse) Alaskan Klee Kai
# en.wikipedia.org (imageinfo) File:WOWAKK-Kukai-Alaskan-Klee-Kai.jpg
# Alaskan Klee Kai (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:WOWAKK-Ku...
#   infobox: <dict(14)> image, image_caption, name, altname, country...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 3074169
#   parsetree: <str(17021)> <root><template><title>More footnotes</t...
#   requests: <list(2)> parse, imageinfo
#   title: Alaskan Klee Kai
#   wikibase: Q38152
#   wikidata_url: https://www.wikidata.org/wiki/Q38152
#   wikitext: <str(10973)> {{More footnotes|date=February 2013}}{{In...
# }
# en.wikipedia.org (parse) Alaskan Malamute
# Alaskan Malamute (en) data
# {
#   image: <list(0)>
#   infobox: <dict(30)> image, name, country, nickname, collapse_sta...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Alaskan_Ma...
#   pageid: 274142
#   parsetree: <str(27918)> <root><template><title>Use American Engl...
#   requests: <list(1)> parse
#   title: Alaskan Malamute
#   wikibase: Q21206
#   wikidata_url: https://www.wikidata.org/wiki/Q21206
#   wikitext: <str(20594)> {{Use American English|date=January 2018}...
# }
# en.wikipedia.org (parse) Alaunt
# en.wikipedia.org (imageinfo) File:Alaunt in Adorazione dei Magi b...
# Alaunt (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alaunt in...
#   infobox: <dict(6)> image, image_caption, origin, name, altname, ...
#   pageid: 1868016
#   parsetree: <str(13853)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Alaunt
#   wikibase: Q1147739
#   wikidata_url: https://www.wikidata.org/wiki/Q1147739
#   wikitext: <str(8629)> {{Infobox Dogbreed|image = Alaunt in Adora...
# }
# en.wikipedia.org (parse) Alopekis
# en.wikipedia.org (imageinfo) File:Alopekis drawing.jpg
# Alopekis (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alopekis ...
#   infobox: <dict(15)> image, image_caption, name, altname, nicknam...
#   pageid: 41162210
#   parsetree: <str(22415)> <root><template><title>tone</title><part...
#   requests: <list(2)> parse, imageinfo
#   title: Alopekis
#   wikibase: Q3635150
#   wikidata_url: https://www.wikidata.org/wiki/Q3635150
#   wikitext: <str(18929)> {{tone|date=June 2014}}{{Infobox Dogbreed...
# }
# en.wikipedia.org (parse) Alpine Dachsbracke
# en.wikipedia.org (imageinfo) File:Alpejski gończy krótkonożny g99.jpg
# Alpine Dachsbracke (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alpejski ...
#   infobox: <dict(16)> image, image_caption, name, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 702771
#   parsetree: <str(7158)> <root><template><title>Infobox Dogbreed<c...
#   requests: <list(2)> parse, imageinfo
#   title: Alpine Dachsbracke
#   wikibase: Q37498
#   wikidata_url: https://www.wikidata.org/wiki/Q37498
#   wikitext: <str(5052)> {{Infobox Dogbreed<!-- Put article text AF...
# }
# en.wikipedia.org (parse) Alpine Mastiff
# en.wikipedia.org (imageinfo) File:1815 Alpine Mastiff.jpg
# Alpine Mastiff (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:1815 Alpi...
#   infobox: <dict(5)> image, image_caption, place of origin, name, ...
#   pageid: 20403394
#   parsetree: <str(5941)> <root><template><title>Infobox Dogbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Alpine Mastiff
#   wikibase: Q3399365
#   wikidata_url: https://www.wikidata.org/wiki/Q3399365
#   wikitext: <str(4069)> {{Infobox Dogbreed |image    = 1815_Alpine...
# }
# en.wikipedia.org (parse) Alpine Spaniel
# en.wikipedia.org (imageinfo) File:Alpine spaniel.jpg
# Alpine Spaniel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Alpine sp...
#   infobox: <dict(6)> name, image, image_caption, altname, country,...
#   pageid: 25160321
#   parsetree: <str(15722)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Alpine Spaniel
#   wikibase: Q4735522
#   wikidata_url: https://www.wikidata.org/wiki/Q4735522
#   wikitext: <str(12290)> {{about|the extinct breed of Swiss rescue...
# }
# en.wikipedia.org (parse) Akita (dog)
# en.wikipedia.org (imageinfo) File:Akita_Inu_dog.jpg
# Akita (dog) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Akita_Inu...
#   infobox: <dict(35)> name, altname, image, country, collapse_stan...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 59064
#   parsetree: <str(67598)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Akita (dog)
#   wikibase: Q29164
#   wikidata_url: https://www.wikidata.org/wiki/Q29164
#   wikitext: <str(50739)> {{Infobox dog breed<!-- Put article text ...
# }
# en.wikipedia.org (parse) American Bully
# en.wikipedia.org (imageinfo) File:Champion Charlie Muscles (2).jpg
# American Bully (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Champion ...
#   infobox: <dict(14)> name, image, image_caption, nickname, countr...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/American_Bully
#   pageid: 24305087
#   parsetree: <str(11571)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: American Bully
#   wikibase: Q5570
#   wikidata_url: https://www.wikidata.org/wiki/Q5570
#   wikitext: <str(7748)> {{about|the dog breed|the film|Anytown (fi...
# }
# en.wikipedia.org (parse) American Bulldog
# en.wikipedia.org (imageinfo) File:Faithfullbull Spike of Mightybull.jpg
# American Bulldog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Faithfull...
#   infobox: <dict(16)> image, image_caption, image_size, name, altn...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 644051
#   parsetree: <str(18540)> <root><template><title>For</title><part>...
#   requests: <list(2)> parse, imageinfo
#   title: American Bulldog
#   wikibase: Q37604
#   wikidata_url: https://www.wikidata.org/wiki/Q37604
#   wikitext: <str(13822)> {{For|other bulldogs|Bulldog (disambiguat...
# }
# en.wikipedia.org (parse) American Cocker Spaniel
# en.wikipedia.org (imageinfo) File:American Cocker in Tallinn 2.JPG
# American Cocker Spaniel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:American ...
#   infobox: <dict(26)> image, image_caption, name, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 273940
#   parsetree: <str(37996)> <root><template><title>good article</tit...
#   requests: <list(2)> parse, imageinfo
#   title: American Cocker Spaniel
#   wikibase: Q38063
#   wikidata_url: https://www.wikidata.org/wiki/Q38063
#   wikitext: <str(28027)> {{good article}}{{Infobox dog breed<!-- P...
# }
# en.wikipedia.org (parse) American English Coonhound
# en.wikipedia.org (imageinfo) File:English Coonhound.jpg
# American English Coonhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:English C...
#   infobox: <dict(13)> image, image_caption, name, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:E...
#   pageid: 18214517
#   parsetree: <str(15829)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: American English Coonhound
#   wikibase: Q37578
#   wikidata_url: https://www.wikidata.org/wiki/Q37578
#   wikitext: <str(11804)> {{Infobox Dogbreed <!-- Put article text ...
# }
# en.wikipedia.org (parse) American Eskimo Dog
# en.wikipedia.org (imageinfo) File:American Eskimo Dog 1.jpg
# American Eskimo Dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:American ...
#   infobox: <dict(16)> image, image_caption, altname, nickname, cou...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 174751
#   parsetree: <str(14324)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: American Eskimo Dog
#   wikibase: Q37699
#   wikidata_url: https://www.wikidata.org/wiki/Q37699
#   wikitext: <str(11504)> {{Infobox dog breed<!-- Put article text ...
# }
# en.wikipedia.org (parse) American Foxhound
# en.wikipedia.org (imageinfo) File:AmericanFoxhound2.jpg
# American Foxhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:AmericanF...
#   infobox: <dict(22)> image, image_caption, name, country, nicknam...
#   pageid: 2208001
#   parsetree: <str(12485)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: American Foxhound
#   wikibase: Q37514
#   wikidata_url: https://www.wikidata.org/wiki/Q37514
#   wikitext: <str(7973)> {{Use dmy dates|date=March 2012}}{{refimpr...
# }
# en.wikipedia.org (parse) American Hairless Terrier
# en.wikipedia.org (imageinfo) File:TagnonPond9-6-03.jpg
# American Hairless Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:TagnonPon...
#   infobox: <dict(16)> image, image_caption, name, country, nicknam...
#   pageid: 826564
#   parsetree: <str(14323)> <root><template><title>multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: American Hairless Terrier
#   wikibase: Q37508
#   wikidata_url: https://www.wikidata.org/wiki/Q37508
#   wikitext: <str(11373)> {{multiple issues|{{weasel|date=September...
# }
# en.wikipedia.org (parse) American Leopard Hound
# en.wikipedia.org (imageinfo) File:Lep2.jpg
# American Leopard Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Lep2.jpg'...
#   infobox: <dict(10)> name, image, country, height, weight, coat, ...
#   pageid: 21858277
#   parsetree: <str(3337)> <root><template><title>Infobox dog breed ...
#   requests: <list(2)> parse, imageinfo
#   title: American Leopard Hound
#   wikibase: Q465537
#   wikidata_url: https://www.wikidata.org/wiki/Q465537
#   wikitext: <str(2225)> {{Infobox dog breed |name = American Leopa...
# }
# en.wikipedia.org (parse) American Pit Bull Terrier
# en.wikipedia.org (imageinfo) File:Ginger December 3579836414e4b5c...
# American Pit Bull Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ginger De...
#   infobox: <dict(18)> name, image, altname, nickname, stock, count...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/American_P...
#   pageid: 1137915
#   parsetree: <str(51443)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: American Pit Bull Terrier
#   wikibase: Q37612
#   wikidata_url: https://www.wikidata.org/wiki/Q37612
#   wikitext: <str(39820)> {{short description|Dog breed}}{{about|th...
# }
# en.wikipedia.org (parse) American Staffordshire Terrier
# en.wikipedia.org (imageinfo) File:AMERICAN STAFFORDSHIRE TERRIER,...
# American Staffordshire Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:AMERICAN ...
#   infobox: <dict(25)> name, image, caption, image_alt, nickname, c...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 1250387
#   parsetree: <str(16733)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: American Staffordshire Terrier
#   wikibase: Q37688
#   wikidata_url: https://www.wikidata.org/wiki/Q37688
#   wikitext: <str(11519)> {{Infobox Dogbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) American Water Spaniel
# en.wikipedia.org (imageinfo) File:Chien d'eau americain champion 1.JPG
# American Water Spaniel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': "File:Chien d'e...
#   infobox: <dict(25)> image, image_caption, name, altname, nicknam...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 274123
#   parsetree: <str(24964)> <root><template><title>good article</tit...
#   requests: <list(2)> parse, imageinfo
#   title: American Water Spaniel
#   wikibase: Q37856
#   wikidata_url: https://www.wikidata.org/wiki/Q37856
#   wikitext: <str(16654)> {{good article}}{{Infobox Dogbreed<!-- Pu...
# }
# en.wikipedia.org (parse) Anatolian Shepherd Dog
# en.wikipedia.org (imageinfo) File:Varish.jpg
# Anatolian Shepherd (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Varish.jp...
#   infobox: <dict(29)> image, image_caption, maleweight, femaleweig...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Anatolian_...
#   pageid: 1181418
#   parsetree: <str(25917)> <root><template><title>Merge </title><pa...
#   requests: <list(2)> parse, imageinfo
#   title: Anatolian Shepherd
#   wikibase: Q37541
#   wikidata_url: https://www.wikidata.org/wiki/Q37541
#   wikitext: <str(19245)> {{Merge |Kangal Shepherd Dog |date=August...
# }
# en.wikipedia.org (parse) Andalusian Hound
# en.wikipedia.org (imageinfo) File:Podenco chico resized.jpg
# Andalusian Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Podenco c...
#   infobox: <dict(20)> image, image_caption, akcgroup, akcstd, altn...
#   pageid: 29047887
#   parsetree: <str(11894)> <root><comment>&lt;!-- Begin Infobox dog...
#   requests: <list(2)> parse, imageinfo
#   title: Andalusian Hound
#   wikibase: Q39262
#   wikidata_url: https://www.wikidata.org/wiki/Q39262
#   wikitext: <str(6827)> <!-- Begin Infobox dog breed. The text of ...
# }
# en.wikipedia.org (parse) Anglo-Français de Petite Vénerie
# en.wikipedia.org (imageinfo) File:Anglo-Français de petite vénerie.jpg
# Anglo-Français de Petite Vénerie (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Anglo-Fra...
#   infobox: <dict(13)> image, image_caption, name, country, height,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 10861305
#   parsetree: <str(8524)> <root><template><title>Infobox Dogbreed<c...
#   requests: <list(2)> parse, imageinfo
#   title: Anglo-Français de Petite Vénerie
#   wikibase: Q37482
#   wikidata_url: https://www.wikidata.org/wiki/Q37482
#   wikitext: <str(6143)> {{Infobox Dogbreed<!-- Put article text AF...
# }
# en.wikipedia.org (parse) Appenzeller Sennenhund
# en.wikipedia.org (imageinfo) File:Dara essy.jpg
# Appenzeller Sennenhund (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Dara essy...
#   infobox: <dict(16)> image, image_caption, name, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 3037364
#   parsetree: <str(10527)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Appenzeller Sennenhund
#   wikibase: Q37697
#   wikidata_url: https://www.wikidata.org/wiki/Q37697
#   wikitext: <str(7433)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Argentine Pila Dog
# Argentine Pila Dog (en) data
# {
#   pageid: 38224339
#   parsetree: <str(14316)> <root>[[File:Perro-pila-pilichy.jpg|thum...
#   requests: <list(1)> parse
#   title: Argentine Pila Dog
#   wikibase: Q3092983
#   wikidata_url: https://www.wikidata.org/wiki/Q3092983
#   wikitext: <str(13595)> [[File:Perro-pila-pilichy.jpg|thumb|right...
# }
# en.wikipedia.org (parse) Argentine Polar Dog
# Argentine Polar Dog (en) data
# {
#   image: <list(0)>
#   infobox: <dict(7)> name, image, image_caption, altname, maleweig...
#   iwlinks: <list(1)> https://es.wikipedia.org/wiki/Perro_polar_arg...
#   pageid: 58949274
#   parsetree: <str(17262)> <root><template><title>no footnotes</tit...
#   requests: <list(1)> parse
#   title: Argentine Polar Dog
#   wikibase: Q9058633
#   wikidata_url: https://www.wikidata.org/wiki/Q9058633
#   wikitext: <str(13485)> {{no footnotes|date=March 2019 }}{{refimp...
# }
# en.wikipedia.org (parse) Ariegeois
# en.wikipedia.org (imageinfo) File:Ariegeois.jpg
# Ariegeois (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ariegeois...
#   infobox: <dict(15)> name, image, image_caption, altname, country...
#   pageid: 8340330
#   parsetree: <str(7347)> <root><template><title>dablink</title><pa...
#   requests: <list(2)> parse, imageinfo
#   title: Ariegeois
#   wikibase: Q37487
#   wikidata_url: https://www.wikidata.org/wiki/Q37487
#   wikitext: <str(3850)> {{dablink|For the "Ariègeois Pony", please...
# }
# en.wikipedia.org (parse) Armant (dog)
# en.wikipedia.org (imageinfo) File:Armant dog, with some orange st...
# Armant dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Armant do...
#   infobox: <dict(6)> name, image, image_caption, altname, nickname...
#   pageid: 18403019
#   parsetree: <str(6349)> <root><template><title>Infobox Dogbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Armant dog
#   wikibase: Q37872
#   wikidata_url: https://www.wikidata.org/wiki/Q37872
#   wikitext: <str(4537)> {{Infobox Dogbreed | name = Armant| image ...
# }
# en.wikipedia.org (parse) Armenian Gampr dog
# en.wikipedia.org (imageinfo) File:Gampr-armenian-wolfhound.jpg
# Armenian Gampr dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Gampr-arm...
#   infobox: <dict(14)> altname, country, image_caption, name, nickn...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 24233836
#   parsetree: <str(14834)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Armenian Gampr dog
#   wikibase: Q38219
#   wikidata_url: https://www.wikidata.org/wiki/Q38219
#   wikitext: <str(9140)> {{Infobox Dogbreed| akcgroup =| akcstd =| ...
# }
# en.wikipedia.org (parse) Artois Hound
# en.wikipedia.org (imageinfo) File:Artois from 1915.JPG
# Artois Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Artois fr...
#   infobox: <dict(11)> image, image_caption, name, altname, country...
#   pageid: 2277649
#   parsetree: <str(15178)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Artois Hound
#   wikibase: Q37758
#   wikidata_url: https://www.wikidata.org/wiki/Q37758
#   wikitext: <str(11550)> {{More citations needed|date=December 201...
# }
# en.wikipedia.org (parse) Australian Cattle Dog
# en.wikipedia.org (imageinfo) File:ACD-blue-spud.jpg
# Australian Cattle Dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:ACD-blue-...
#   infobox: <dict(26)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 445359
#   parsetree: <str(74093)> <root><template><title>pp-semi-indef</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Cattle Dog
#   wikibase: Q37595
#   wikidata_url: https://www.wikidata.org/wiki/Q37595
#   wikitext: <str(53311)> {{pp-semi-indef}}{{short description|A br...
# }
# en.wikipedia.org (parse) Australian Kelpie
# en.wikipedia.org (imageinfo) File:Hilu the Australian Kelpie dog.jpg
# Australian Kelpie (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Hilu the ...
#   infobox: <dict(25)> name, image, image_caption, altname, nicknam...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 62895
#   parsetree: <str(27278)> <root><template><title>About</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Kelpie
#   wikibase: Q37520
#   wikidata_url: https://www.wikidata.org/wiki/Q37520
#   wikitext: <str(19281)> {{About|the dog breed|the aquatic creatur...
# }
# en.wikipedia.org (parse) Australian Shepherd
# en.wikipedia.org (imageinfo) File:Redtriaussie01.jpg
# Australian Shepherd (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Redtriaus...
#   infobox: <dict(29)> image, image_caption, status, nickname, coun...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Australian...
#   pageid: 514816
#   parsetree: <str(54745)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Shepherd
#   wikibase: Q37629
#   wikidata_url: https://www.wikidata.org/wiki/Q37629
#   wikitext: <str(42117)> {{Infobox dog breed<!-- Put article text ...
# }
# en.wikipedia.org (parse) Australian Stumpy Tail Cattle Dog
# en.wikipedia.org (imageinfo) File:Australian Stumpy Tail Cattle Dog.jpg
# Australian Stumpy Tail Cattle Dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Australia...
#   infobox: <dict(24)> name, image, altname, nickname, country, hei...
#   pageid: 3069338
#   parsetree: <str(14815)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Stumpy Tail Cattle Dog
#   wikibase: Q37503
#   wikidata_url: https://www.wikidata.org/wiki/Q37503
#   wikitext: <str(9753)> {{Infobox dog breed|name     = Australian ...
# }
# en.wikipedia.org (parse) Australian Terrier
# en.wikipedia.org (imageinfo) File:Australian Terrier adult male.jpg
# Australian Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Australia...
#   infobox: <dict(26)> image, image_caption, name, country, nicknam...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:A...
#   pageid: 487538
#   parsetree: <str(14022)> <root> <template lineStart="1"><title>Us...
#   requests: <list(2)> parse, imageinfo
#   title: Australian Terrier
#   wikibase: Q37530
#   wikidata_url: https://www.wikidata.org/wiki/Q37530
#   wikitext: <str(9481)> {{Use dmy dates|date=November 2015}}{{Use ...
# }
# en.wikipedia.org (parse) Austrian Black and Tan Hound
# en.wikipedia.org (imageinfo) File:Brandlbracke.JPG
# Austrian Black and Tan Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Brandlbra...
#   infobox: <dict(17)> name, image, altname, nickname, country, wei...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 8096827
#   parsetree: <str(7792)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Austrian Black and Tan Hound
#   wikibase: Q11385
#   wikidata_url: https://www.wikidata.org/wiki/Q11385
#   wikitext: <str(3869)> {{Refimprove|date=September 2014}}{{Infobo...
# }
# en.wikipedia.org (parse) Austrian Pinscher
# en.wikipedia.org (imageinfo) File:Pinczer austiacki 678.jpg
# Austrian Pinscher (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Pinczer a...
#   infobox: <dict(12)> name, image, altname, country, maleheight, f...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/%C3%96ster...
#   pageid: 8096895
#   parsetree: <str(11549)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Austrian Pinscher
#   wikibase: Q38426
#   wikidata_url: https://www.wikidata.org/wiki/Q38426
#   wikitext: <str(8212)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Azawakh
# en.wikipedia.org (imageinfo) File:Bistrita 2015 (22).jpg
# Azawakh (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bistrita ...
#   infobox: <dict(28)> name, image, image_alt, image_caption, altna...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 2836
#   parsetree: <str(22121)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Azawakh
#   wikibase: Q37859
#   wikidata_url: https://www.wikidata.org/wiki/Q37859
#   wikitext: <str(16089)> {{Infobox dog breed<!-- Put article text ...
# }
# en.wikipedia.org (parse) Bakharwal dog
# Bakharwal dog (en) data
# {
#   infobox: <dict(6)> name, altname, country, notrecognised, colour...
#   pageid: 4207732
#   parsetree: <str(11830)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(1)> parse
#   title: Bakharwal dog
#   wikibase: Q37653
#   wikidata_url: https://www.wikidata.org/wiki/Q37653
#   wikitext: <str(9617)> {{Infobox Dogbreed| name = Bakharwal Dog| ...
# }
# en.wikipedia.org (parse) Barbado da Terceira
# en.wikipedia.org (imageinfo) File:Barbado da Terceira (young fema...
# Barbado da Terceira (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Barbado d...
#   infobox: <dict(11)> image, image_caption, name, altname, country...
#   pageid: 43688597
#   parsetree: <str(5265)> <root><template><title>No footnotes</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Barbado da Terceira
#   wikibase: Q168788
#   wikidata_url: https://www.wikidata.org/wiki/Q168788
#   wikitext: <str(3941)> {{No footnotes|date=March 2018}}{{Infobox ...
# }
# en.wikipedia.org (parse) Barbet (dog)
# en.wikipedia.org (imageinfo) File:Chien de race Barbet.jpg
# Barbet dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Chien de ...
#   infobox: <dict(19)> image, name, altname, country, maleheight, f...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Barbet
#   pageid: 275441
#   parsetree: <str(18187)> <root><template><title>Other uses</title...
#   requests: <list(2)> parse, imageinfo
#   title: Barbet dog
#   wikibase: Q37585
#   wikidata_url: https://www.wikidata.org/wiki/Q37585
#   wikitext: <str(11532)> {{Other uses|Barbet (disambiguation){{!}}...
# }
# en.wikipedia.org (parse) Basenji
# en.wikipedia.org (imageinfo) File:Basenji Profile (loosercrop).jpg
# Basenji (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Basenji P...
#   infobox: <dict(28)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 4765
#   parsetree: <str(37759)> <root><template><title>about</title><par...
#   requests: <list(2)> parse, imageinfo
#   title: Basenji
#   wikibase: Q37871
#   wikidata_url: https://www.wikidata.org/wiki/Q37871
#   wikitext: <str(29007)> {{about|the dog breed|the musician|Basenj...
# }
# en.wikipedia.org (parse) Basque Shepherd Dog
# en.wikipedia.org (imageinfo) File:Pastor vasco m 14months loby 3018.jpg
# Basque Shepherd Dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Pastor va...
#   infobox: <dict(13)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 8460098
#   parsetree: <str(12327)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Basque Shepherd Dog
#   wikibase: Q38653
#   wikidata_url: https://www.wikidata.org/wiki/Q38653
#   wikitext: <str(6718)> {{Infobox dog breed|name     = Basque Shep...
# }
# en.wikipedia.org (parse) Basset Artésien Normand
# en.wikipedia.org (imageinfo) File:Grupp 6 BASSET ARTÉSIEN NORMAND...
# Basset Artésien Normand (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Grupp 6 B...
#   infobox: <dict(15)> image, image_caption, name, nickname, countr...
#   pageid: 19515834
#   parsetree: <str(6860)> <root><template><title>Infobox Dogbreed<c...
#   requests: <list(2)> parse, imageinfo
#   title: Basset Artésien Normand
#   wikibase: Q37561
#   wikidata_url: https://www.wikidata.org/wiki/Q37561
#   wikitext: <str(4317)> {{Infobox Dogbreed<!-- Put article text AF...
# }
# en.wikipedia.org (parse) Basset Bleu de Gascogne
# en.wikipedia.org (imageinfo) File:Basset bleu de Gascogne.jpg
# Basset Bleu de Gascogne (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Basset bl...
#   infobox: <dict(17)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 7615066
#   parsetree: <str(12887)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Basset Bleu de Gascogne
#   wikibase: Q37552
#   wikidata_url: https://www.wikidata.org/wiki/Q37552
#   wikitext: <str(8483)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Basset Fauve de Bretagne
# en.wikipedia.org (imageinfo) File:Basset Fauve de Bretagne 600.jpg
# Basset Fauve de Bretagne (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Basset Fa...
#   infobox: <dict(21)> image, image_caption, name, altname, country...
#   pageid: 621843
#   parsetree: <str(10934)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Basset Fauve de Bretagne
#   wikibase: Q37570
#   wikidata_url: https://www.wikidata.org/wiki/Q37570
#   wikitext: <str(8134)> {{Refimprove|date=July 2007}}{{Infobox Dog...
# }
# en.wikipedia.org (parse) Basset Hound
# en.wikipedia.org (imageinfo) File:BassetHound profil.jpg
# Basset Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:BassetHou...
#   infobox: <dict(26)> name, image, image_caption, origin, weight, ...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 68453
#   parsetree: <str(31625)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Basset Hound
#   wikibase: Q37716
#   wikidata_url: https://www.wikidata.org/wiki/Q37716
#   wikitext: <str(24188)> {{Infobox dog breed| name          = Bass...
# }
# en.wikipedia.org (parse) Bavarian Mountain Hound
# en.wikipedia.org (imageinfo) File:Zoran Spod Ruskiej Granicy the ...
# Bavarian Mountain Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Zoran Spo...
#   infobox: <dict(17)> name, image, maleheight, femaleheight, coat,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Bavarian_M...
#   pageid: 3095466
#   parsetree: <str(8329)> <root><template><title>Refimprove</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Bavarian Mountain Hound
#   wikibase: Q37576
#   wikidata_url: https://www.wikidata.org/wiki/Q37576
#   wikitext: <str(4735)> {{Refimprove|date=December 2012}}{{Infobox...
# }
# en.wikipedia.org (parse) Beagle
# en.wikipedia.org (imageinfo) File:Beagle 600.jpg
# Beagle (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Beagle 60...
#   infobox: <dict(28)> name, image, image_alt, image_caption, altna...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Beagle
#   pageid: 4368
#   parsetree: <str(83671)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Beagle
#   wikibase: Q21102
#   wikidata_url: https://www.wikidata.org/wiki/Q21102
#   wikitext: <str(61660)> {{short description|A breed of small scen...
# }
# en.wikipedia.org (parse) Beagle-Harrier
# en.wikipedia.org (imageinfo) File:Beagle harrier.JPG
# Beagle-Harrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Beagle ha...
#   infobox: <dict(13)> name, image, image_caption, country, height,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 9858055
#   parsetree: <str(9033)> <root><template><title>Infobox Dogbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Beagle-Harrier
#   wikibase: Q37478
#   wikidata_url: https://www.wikidata.org/wiki/Q37478
#   wikitext: <str(4710)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Bearded Collie
# en.wikipedia.org (imageinfo) File:Bearded Collie 600.jpg
# Bearded Collie (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bearded C...
#   infobox: <dict(28)> name, image, altname, nickname, country, wei...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 547121
#   parsetree: <str(24410)> <root><template><title>More citations ne...
#   requests: <list(2)> parse, imageinfo
#   title: Bearded Collie
#   wikibase: Q37619
#   wikidata_url: https://www.wikidata.org/wiki/Q37619
#   wikitext: <str(17553)> {{More citations needed|date=July 2007}}{...
# }
# en.wikipedia.org (parse) Beauceron
# en.wikipedia.org (imageinfo) File:Owczarek francuski beauceron 00...
# Beauceron (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Owczarek ...
#   infobox: <dict(23)> name, image, image_caption, altname, country...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Special:Se...
#   pageid: 275617
#   parsetree: <str(16423)> <root> <template lineStart="1"><title>mo...
#   requests: <list(2)> parse, imageinfo
#   title: Beauceron
#   wikibase: Q37720
#   wikidata_url: https://www.wikidata.org/wiki/Q37720
#   wikitext: <str(10887)> {{more footnotes|date=December 2014}}{{In...
# }
# en.wikipedia.org (parse) Bedlington Terrier
# en.wikipedia.org (imageinfo) File:Boutchie apres championnat 004.JPG
# Bedlington Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Boutchie ...
#   infobox: <dict(27)> name, image, altname, country, weight, maleh...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 611087
#   parsetree: <str(36761)> <root><template><title>for</title><part>...
#   requests: <list(2)> parse, imageinfo
#   title: Bedlington Terrier
#   wikibase: Q37582
#   wikidata_url: https://www.wikidata.org/wiki/Q37582
#   wikitext: <str(24805)> {{for|the football club|Bedlington Terrie...
# }
# en.wikipedia.org (parse) Groenendael dog
# en.wikipedia.org (imageinfo) File:Groenendael.jpg
# Groenendael dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Groenenda...
#   infobox: <dict(29)> name, image, image_alt, altname, country, ma...
#   iwlinks: <list(4)> https://en.wikibooks.org/wiki/, https://en.wi...
#   pageid: 602973
#   parsetree: <str(13512)> <root><template><title>Refimprove</title...
#   requests: <list(2)> parse, imageinfo
#   title: Groenendael dog
#   wikibase: Q38399
#   wikidata_url: https://www.wikidata.org/wiki/Q38399
#   wikitext: <str(7198)> {{Refimprove|date=February 2007}}{{Infobox...
# }
# en.wikipedia.org (parse) Laekenois dog
# en.wikipedia.org (imageinfo) File:Fang-sitt-040728.jpg
# Laekenois dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Fang-sitt...
#   infobox: <dict(29)> name, image, altname, country, maleweight, f...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Belgian_Sh...
#   pageid: 602988
#   parsetree: <str(11223)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Laekenois dog
#   wikibase: Q37815
#   wikidata_url: https://www.wikidata.org/wiki/Q37815
#   wikitext: <str(6213)> {{Infobox dog breed|name     = Laekenois (...
# }
# en.wikipedia.org (parse) Malinois dog
# en.wikipedia.org (imageinfo) File:Female Malinois 2005-01-29.jpg
# Malinois dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Female Ma...
#   infobox: <dict(27)> name, image, altname, country, maleweight, f...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 603016
#   parsetree: <str(30055)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Malinois dog
#   wikibase: Q38494
#   wikidata_url: https://www.wikidata.org/wiki/Q38494
#   wikitext: <str(19367)> {{short description|Type of Belgian Sheph...
# }
# en.wikipedia.org (parse) Tervuren dog
# en.wikipedia.org (imageinfo) File:Tervueren.jpg
# Tervuren dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tervueren...
#   infobox: <dict(25)> name, image, altname, femaleweight, maleheig...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 603028
#   parsetree: <str(15060)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Tervuren dog
#   wikibase: Q38679
#   wikidata_url: https://www.wikidata.org/wiki/Q38679
#   wikitext: <str(10747)> {{Use dmy dates|date=September 2015}}{{In...
# }
# en.wikipedia.org (parse) Bergamasco Shepherd
# en.wikipedia.org (imageinfo) File:Bergamasco shepherd dog - merle...
# Bergamasco Shepherd (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bergamasc...
#   infobox: <dict(24)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Bergamasco
#   pageid: 621910
#   parsetree: <str(13004)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Bergamasco Shepherd
#   wikibase: Q38238
#   wikidata_url: https://www.wikidata.org/wiki/Q38238
#   wikitext: <str(8707)> {{Infobox dog breed|name     = Bergamasco ...
# }
# en.wikipedia.org (parse) Berger Blanc Suisse
# en.wikipedia.org (imageinfo) File:20180320 White Shepherd 2.jpg
# Berger Blanc Suisse (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:20180320 ...
#   infobox: <dict(22)> image, image_caption, name, altname, country...
#   pageid: 14465264
#   parsetree: <str(10369)> <root><template><title>multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: Berger Blanc Suisse
#   wikibase: Q37934
#   wikidata_url: https://www.wikidata.org/wiki/Q37934
#   wikitext: <str(5814)> {{multiple issues|{{refimprove|date=Decemb...
# }
# en.wikipedia.org (parse) Berger Picard
# en.wikipedia.org (imageinfo) File:Picard Delice Stacked.jpg
# Berger Picard (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Picard De...
#   infobox: <dict(22)> name, image, image_caption, altname, country...
#   iwlinks: <list(1)> https://it.wikipedia.org/wiki/Cane_da_pastore...
#   pageid: 4527371
#   parsetree: <str(20223)> <root><template><title>multiple issues</...
#   requests: <list(2)> parse, imageinfo
#   title: Berger Picard
#   wikibase: Q37635
#   wikidata_url: https://www.wikidata.org/wiki/Q37635
#   wikitext: <str(12553)> {{multiple issues|{{Original research|dat...
# }
# en.wikipedia.org (parse) Bernese Mountain Dog
# en.wikipedia.org (imageinfo) File:Othello.jpg
# Bernese Mountain Dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Othello.j...
#   infobox: <dict(30)> image, image_caption, name, altname, country...
#   iwlinks: <list(2)> https://commons.wikimedia.org/wiki/Berner_Sen...
#   pageid: 274779
#   parsetree: <str(56881)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Bernese Mountain Dog
#   wikibase: Q37608
#   wikidata_url: https://www.wikidata.org/wiki/Q37608
#   wikitext: <str(38274)> {{Infobox Dogbreed<!-- Put article text A...
# }
# en.wikipedia.org (parse) Bichon Frisé
# en.wikipedia.org (imageinfo) File:Bichon Frisé - studdogbichon.jpg
# Bichon Frise (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bichon Fr...
#   infobox: <dict(25)> name, image, altname, country, height, coat,...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Bichon_Fri...
#   pageid: 95910
#   parsetree: <str(33888)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Bichon Frise
#   wikibase: Q37600
#   wikidata_url: https://www.wikidata.org/wiki/Q37600
#   wikitext: <str(23653)> {{Use dmy dates|date=February 2015}}{{Inf...
# }
# en.wikipedia.org (parse) Billy (dog)
# en.wikipedia.org (imageinfo) File:Poitou Hound from 1915.JPG
# Billy (dog) (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Poitou Ho...
#   infobox: <dict(14)> name, image, image_caption, country, malehei...
#   pageid: 6920767
#   parsetree: <str(7059)> <root><template><title>Infobox Dogbreed <...
#   requests: <list(2)> parse, imageinfo
#   title: Billy (dog)
#   wikibase: Q37637
#   wikidata_url: https://www.wikidata.org/wiki/Q37637
#   wikitext: <str(3832)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Black and Tan Coonhound
# en.wikipedia.org (imageinfo) File:Black and Tan Coonhound.jpg
# Black and Tan Coonhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Black and...
#   infobox: <dict(25)> name, image, altname, country, weight, malew...
#   pageid: 206213
#   parsetree: <str(14111)> <root><comment>&lt;!-- Put article text ...
#   requests: <list(2)> parse, imageinfo
#   title: Black and Tan Coonhound
#   wikibase: Q37537
#   wikidata_url: https://www.wikidata.org/wiki/Q37537
#   wikitext: <str(7783)> <!-- Put article text AFTER this infobox m...
# }
# en.wikipedia.org (parse) Black and Tan Virginia Foxhound
# Black and Tan Virginia Foxhound (en) data
# {
#   infobox: <dict(8)> name, country, weight, height, coat, color, l...
#   pageid: 17707528
#   parsetree: <str(7494)> <root><template><title>Refimprove</title>...
#   requests: <list(1)> parse
#   title: Black and Tan Virginia Foxhound
#   wikibase: Q38353
#   wikidata_url: https://www.wikidata.org/wiki/Q38353
#   wikitext: <str(4158)> {{Refimprove|date=November 2018}}{{Infobox...
# }
# en.wikipedia.org (parse) Black Norwegian Elkhound
# en.wikipedia.org (imageinfo) File:BlackNorwegianElkhound.jpg
# Black Norwegian Elkhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:BlackNorw...
#   infobox: <dict(15)> name, image, image_alt, image_caption, altna...
#   pageid: 8671317
#   parsetree: <str(10776)> <root><comment>&lt;!-- Begin Infobox Dog...
#   requests: <list(2)> parse, imageinfo
#   title: Black Norwegian Elkhound
#   wikibase: Q38961
#   wikidata_url: https://www.wikidata.org/wiki/Q38961
#   wikitext: <str(6283)> <!-- Begin Infobox Dogbreed. The text of t...
# }
# en.wikipedia.org (parse) Black Russian Terrier
# en.wikipedia.org (imageinfo) File:Russianblack.jpg
# Black Russian Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Russianbl...
#   infobox: <dict(18)> image, name, altname, akcgroup, akcstd, coun...
#   iwlinks: <list(5)> https://commons.wikimedia.org/wiki/Category:T...
#   pageid: 999011
#   parsetree: <str(15015)> <root><template><title>Infobox Dogbreed<...
#   requests: <list(2)> parse, imageinfo
#   title: Black Russian Terrier
#   wikibase: Q38634
#   wikidata_url: https://www.wikidata.org/wiki/Q38634
#   wikitext: <str(10875)> {{Infobox Dogbreed| image = Russianblack....
# }
# en.wikipedia.org (parse) Black Mouth Cur
# en.wikipedia.org (imageinfo) File:Black mouth cur-10.jpg
# Black Mouth Cur (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Black mou...
#   infobox: <dict(12)> name, altname, origin, image, maleweight, fe...
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:B...
#   pageid: 7376329
#   parsetree: <str(14067)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Black Mouth Cur
#   wikibase: Q38556
#   wikidata_url: https://www.wikidata.org/wiki/Q38556
#   wikitext: <str(9892)> {{Infobox Dogbreed <!-- Put article text A...
# }
# en.wikipedia.org (parse) Bloodhound
# en.wikipedia.org (imageinfo) File:Bloodhound red black pigmented.jpg
# Bloodhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Bloodhoun...
#   infobox: <dict(28)> image, image_caption, name, altname, country...
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Chien_de_S...
#   pageid: 22220263
#   parsetree: <str(71966)> <root><template><title>short description...
#   requests: <list(2)> parse, imageinfo
#   title: Bloodhound
#   wikibase: Q21098
#   wikidata_url: https://www.wikidata.org/wiki/Q21098
# ...
#   wikitext: <str(6731)> <!-- Begin Infobox Dogbreed. The text of t...
# }
# en.wikipedia.org (parse) Toy Manchester Terrier
# en.wikipedia.org (imageinfo) File:Toy-manchester-terrier-weave.png
# Toy Manchester Terrier (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Toy-manch...
#   infobox: <dict(13)> image, image_caption, name, altname, country...
#   pageid: 727677
#   parsetree: <str(8282)> <root><comment>&lt;!-- Begin Infobox Dogb...
#   requests: <list(2)> parse, imageinfo
#   title: Toy Manchester Terrier
#   wikibase: Q39407
#   wikidata_url: https://www.wikidata.org/wiki/Q39407
#   wikitext: <str(6248)> <!-- Begin Infobox Dogbreed.  The text of ...
# }
# en.wikipedia.org (parse) Toy Trawler Spaniel
# en.wikipedia.org (imageinfo) File:Trawler spaniel goblin.jpg
# Toy Trawler Spaniel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Trawler s...
#   infobox: <dict(6)> country, image, image_caption, name, altname,...
#   pageid: 25242924
#   parsetree: <str(7473)> <root><template><title>Infobox Dogbreed</...
#   requests: <list(2)> parse, imageinfo
#   title: Toy Trawler Spaniel
#   wikibase: Q39151
#   wikidata_url: https://www.wikidata.org/wiki/Q39151
#   wikitext: <str(4513)> {{Infobox Dogbreed| country = United Kingd...
# }
# en.wikipedia.org (parse) Transylvanian Hound
# en.wikipedia.org (imageinfo) File:Erdelyi kopo VadaszNimrodSzeder01.jpg
# Transylvanian Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Erdelyi k...
#   infobox: <dict(11)> name, image, country, fcigroup, fcisection, ...
#   pageid: 12733574
#   parsetree: <str(19869)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Transylvanian Hound
#   wikibase: Q38394
#   wikidata_url: https://www.wikidata.org/wiki/Q38394
#   wikitext: <str(13834)> {{Infobox Dogbreed <!-- Put article text ...
# }
# en.wikipedia.org (parse) Treeing Cur
# Treeing Cur (en) data
# {
#   infobox: <dict(9)> name, country, weight, height, coat, color, l...
#   pageid: 16967970
#   parsetree: <str(8810)> <root><template><title>one source</title>...
#   requests: <list(1)> parse
#   title: Treeing Cur
#   wikibase: Q39148
#   wikidata_url: https://www.wikidata.org/wiki/Q39148
#   wikitext: <str(4052)> {{one source|date=May 2011}}{{Infobox dog ...
# }
# en.wikipedia.org (parse) Treeing Tennessee Brindle
# en.wikipedia.org (imageinfo) File:Sienna TTBD.jpg
# Treeing Tennessee Brindle (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Sienna TT...
#   infobox: <dict(11)> name, image, country, maleweight, femaleweig...
#   pageid: 32384008
#   parsetree: <str(9666)> <root><template><title>Infobox dog breed<...
#   requests: <list(2)> parse, imageinfo
#   title: Treeing Tennessee Brindle
#   wikibase: Q38443
#   wikidata_url: https://www.wikidata.org/wiki/Q38443
#   wikitext: <str(4176)> {{Infobox dog breed|name     = Treeing Ten...
# }
# en.wikipedia.org (parse) Treeing Walker Coonhound
# en.wikipedia.org (imageinfo) File:Treeing-walker-coonhound-standing.jpg
# Treeing Walker Coonhound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Treeing-w...
#   infobox: <dict(19)> name, image, image_caption, altname, nicknam...
#   pageid: 2370241
#   parsetree: <str(14231)> <root><comment>&lt;!-- Begin Infobox Dog...
#   requests: <list(2)> parse, imageinfo
#   title: Treeing Walker Coonhound
#   wikibase: Q39244
#   wikidata_url: https://www.wikidata.org/wiki/Q39244
#   wikitext: <str(10319)> <!-- Begin Infobox Dogbreed.  The text of...
# }
# en.wikipedia.org (parse) Trigg Hound
# en.wikipedia.org (imageinfo) File:Ned (Trigg).png
# Trigg Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Ned (Trig...
#   infobox: <dict(14)> name, image, image_alt, image_caption, altna...
#   pageid: 31641811
#   parsetree: <str(10456)> <root><template><title>Infobox dog breed...
#   requests: <list(2)> parse, imageinfo
#   title: Trigg Hound
#   wikibase: Q7841691
#   wikidata_url: https://www.wikidata.org/wiki/Q7841691
#   wikitext: <str(4883)> {{Infobox dog breed|name     = Trigg Hound...
# }
# en.wikipedia.org (parse) Turnspit dog
# en.wikipedia.org (imageinfo) File:Turnspitdog-1862.jpg
# Turnspit dog (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Turnspitd...
#   infobox: <dict(6)> image, image_size, image_caption, country, na...
#   iwlinks: <list(2)> http://www.gutenberg.org/etext/26500, https:/...
#   pageid: 5431055
#   parsetree: <str(14119)> <root><template><title>Use dmy dates</ti...
#   requests: <list(2)> parse, imageinfo
#   title: Turnspit dog
#   wikibase: Q39223
#   wikidata_url: https://www.wikidata.org/wiki/Q39223
#   wikitext: <str(10632)> {{Use dmy dates|date=March 2016}}<!-- Beg...
# }
# en.wikipedia.org (parse) Tweed Water Spaniel
# en.wikipedia.org (imageinfo) File:Tweed Water Spaniel.jpg
# Tweed Water Spaniel (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tweed Wat...
#   infobox: <dict(6)> altname, country, image, image_caption, name,...
#   pageid: 5424802
#   parsetree: <str(12686)> <root><template><title>good article</tit...
#   requests: <list(2)> parse, imageinfo
#   title: Tweed Water Spaniel
#   wikibase: Q39188
#   wikidata_url: https://www.wikidata.org/wiki/Q39188
#   wikitext: <str(9775)> {{good article}}<!-- Begin Infobox Dogbree...
# }
# en.wikipedia.org (parse) Tyrolean Hound
# en.wikipedia.org (imageinfo) File:Tiroler Bracke.jpg
# Tyrolean Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Tiroler B...
#   infobox: <dict(9)> name, image, image_caption, altname, country,...
#   pageid: 8098261
#   parsetree: <str(13461)> <root><template><title>Infobox Dogbreed ...
#   requests: <list(2)> parse, imageinfo
#   title: Tyrolean Hound
#   wikibase: Q39084
#   wikidata_url: https://www.wikidata.org/wiki/Q39084
#   wikitext: <str(10670)> {{Infobox Dogbreed <!-- Put article text ...
# }
# en.wikipedia.org (parse) Cimarrón Uruguayo
# en.wikipedia.org (imageinfo) File:Boqueron de Quilligan.JPG
# Cimarrón Uruguayo (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Boqueron ...
#   infobox: <dict(12)> image, image_caption, name, altname, country...
#   pageid: 19674406
#   parsetree: <str(8155)> <root><template><title>Infobox Dogbreed<c...
#   requests: <list(2)> parse, imageinfo
#   title: Cimarrón Uruguayo
#   wikibase: Q37644
#   wikidata_url: https://www.wikidata.org/wiki/Q37644
#   wikitext: <str(5822)> {{Infobox Dogbreed<!-- Put article text AF...
# }
# en.wikipedia.org (parse) Vanjari Hound
# en.wikipedia.org (imageinfo) File:Banjara from 1915.JPG
# Vanjari Hound (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Banjara f...
#   infobox: <dict(4)> image, altname, country, name
#   pageid: 23706074
#   parsetree: <str(2226)> <root><template><title>Unreferenced</titl...
#   requests: <list(2)> parse, imageinfo
#   title: Vanjari Hound
#   wikibase: Q4353915
#   wikidata_url: https://www.wikidata.org/wiki/Q4353915
#   wikitext: <str(1468)> {{Unreferenced|date=March 2013}}<!-- Begin...
# }
# en.wikipedia.org (parse) Villano de las Encartaciones
# en.wikipedia.org (imageinfo) File:Billano arra1.JPG
# Villano de las Encartaciones (en) data
# {
#   image: <list(1)> {'kind': 'parse-image', 'file': 'File:Billano a...
#   infobox: <dict(5)> image, name, altname, nickname, country
#   iwlinks: <list(1)> https://commons.wikimedia.org/wiki/Category:V...
#   pageid: 27170158
#   parsetree: <str(5631)> <root><template><title>one source</title>...
#   requests: <list(2)> parse, imageinfo
#   title: Villano de las Encartaciones
#   wikibase: Q39251
#   wikidata_url: https://www.wikidata.org/wiki/Q39251
#   wikitext: <str(3488)> {{one source|date=January 2015}}{{Expand s...
# }
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000002347E0718D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='en.wikipedia.org', port=80): Max retries exceeded with url: /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Villano+de+las+Encartaciones&format=json&action=query (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002347E0718D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-19-f2da858249d2> in <module>
#      70                 image = 'https://user-images.githubusercontent.com/24848110/33519396-7e56363c-d79d-11e7-969b-09782f5ccbab.png'
#      71
# ---> 72             summary = wikipedia.WikipediaPage(breed).summary
#      73
#      74             dog_df = dog_df.append({'breed':breed, 'summary': summary, 'image': image, 'other_names':other_names,
#
# ~\Anaconda3\lib\site-packages\wikipedia\wikipedia.py in __init__(self, title, pageid, redirect, preload, original_title)
#     297       raise ValueError("Either a title or a pageid must be specified")
#     298
# --> 299     self.__load(redirect=redirect, preload=preload)
#     300
#     301     if preload:
#
# ~\Anaconda3\lib\site-packages\wikipedia\wikipedia.py in __load(self, redirect, preload)
#     334       query_params['pageids'] = self.pageid
#     335
# --> 336     request = _wiki_request(query_params)
#     337
#     338     query = request['query']
#
# ~\Anaconda3\lib\site-packages\wikipedia\wikipedia.py in _wiki_request(params)
#     735     time.sleep(int(wait_time.total_seconds()))
#     736
# --> 737   r = requests.get(API_URL, params=params, headers=headers)
#     738
#     739   if RATE_LIMIT:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='en.wikipedia.org', port=80): Max retries exceeded with url: /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Villano+de+las+Encartaciones&format=json&action=query (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000002347E0718D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
dog_df = dog_df.drop_duplicates(subset = 'breed').drop([0])
dog_df.to_csv('dog.csv', index = True, header = True)
#dog_df.to_json('dog.json', orient='table')
